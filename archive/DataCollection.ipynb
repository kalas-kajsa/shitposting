# %% [markdown]
# ## Dependencies

# %%
import requests
import json
from math import ceil
from time import sleep, time
from datetime import datetime
import pandas as pd
import plotly.express as px
import networkx as nx
BEARER_TOKEN = 'AAAAAAAAAAAAAAAAAAAAACzdHwEAAAAAEfabutP9Ydo80QE%2FaaRNRlnz4SY%3DNvtD1dC4n1YtZjdAwOrCHnx3p8IdjK5s1PbG0rhpQvC8zKROnQ'

# %% [markdown]
# ## Functions and classes

# %% [markdown]
# ### Twitter API access

# %%
#Error Class
class RateLimitError(Exception):
    def __init__(self, text = None):
        RateLimitError.text = text

#### HEADERS TO BE USED IN REQUEST MODULE ####
def create_headers(bearer_token):
    headers = {"Authorization": "Bearer {}".format(bearer_token)}
    return headers

#TODO:
def create_headers_multiple_bearer_tokens():
    pass

def connect_to_endpoint(url, headers = None):
    response = requests.request("GET", url, headers = headers)
    if response.status_code == 429:
        raise RateLimitError(response.text)
    elif response.status_code != 200:
        raise Exception(
            f"""Requested url: {url},
                Request returned an error: {response.status_code} {response.text},
                """)
    return response.json()

# %% [markdown]
# ### Error handling (rate limit use)

# %%
#### HANDLE RATE LIMIT ERROR #####

#Find rate limits that has been used
def rate_limit_use(BEARER_TOKEN):
    headers = create_headers(BEARER_TOKEN)
    path = "https://api.twitter.com/1.1/application/rate_limit_status.json?"
    rate_limit = connect_to_endpoint(path, headers)
    rate_limits_used = {}
    for x in rate_limit['resources']:
        for y in rate_limit['resources'][x]:
            if rate_limit['resources'][x][y]['limit'] != rate_limit['resources'][x][y]['remaining']:
                rate_limits_used.update({y : rate_limit['resources'][x][y]})
    return rate_limits_used

#Find the rate limits that are 0
def rate_limit_exhausted(BEARER_TOKEN):
    d = rate_limit_use(BEARER_TOKEN)
    rate_limit_exhausted = {k : d[k] for k in d if d[k]['remaining'] == 0}
    return rate_limit_exhausted

#Find the waiting time until all rate limits has been recovered 
def rate_limit_recovery_time_max(BEARER_TOKEN):
    dic = rate_limit_exhausted(BEARER_TOKEN)
    epoch_time_max = max([dic[x]['reset'] for x in dic])
    return epoch_time_max

#TODO: #Create new header from BearerToken if zero ratelimit at present
def not_exhausted_bearer_token(BEARER_TOKEN_LIST):
    pass

# %% [markdown]
# ### Building Twitter API urls to get user information and followers

# %%
#### REQUEST TWITTER API ####

#GET metadata on specific user from either user name or user id
def url_lookup_user(usernames = None, ids = None):
    if ids != None: 
        id_or_user_name = f"{ids}?"
    else:
        id_or_user_name = f"by?usernames={usernames}"    
    
    user_fields = ""
    url = f"https://api.twitter.com/2/users/{id_or_user_name}&{user_fields}"
    return url

#GET data on users following user id in question
def url_get_following(user_id):
    # find all metadata (possible userfields, expansions etc.) that can be returned here: 
    # https://developer.twitter.com/en/docs/twitter-api/users/follows/api-reference/get-users-id-following
    user_fields = "user.fields=public_metrics,location,description,verified"
    return f"https://api.twitter.com/2/users/{user_id}/following?max_results=1000&{user_fields}"

# %% [markdown]
# ### Connect to twitter API (request)

# %%
def connect_to_endpoint_pagenation(url_input, BEARER_TOKEN, max_results = 1000):
    #auth
    headers = create_headers(BEARER_TOKEN)
    
    #Input and output
    tokens = ['next_token','previous_token']
    url = url_input
    json_response_gross = {}
    
    i = 1 #enumerator
    
    while True:    
        try:
            json_response = connect_to_endpoint(url, headers)
        except Exception as e:
            if type(e) == RateLimitError:
                #TODO: FUNCTION TO CHECK OTHER BEARER TOKENS AVALAIBLE SHOULD BE INSERTED HERE
                timestamp_ready = rate_limit_recovery_time_max(BEARER_TOKEN)
                seconds_to_wait, minutes_to_wait = timestamp_ready - time(), round((timestamp_ready - time())/60,2)
                time_to_resume = datetime.fromtimestamp(timestamp_ready).strftime("%d/%m/%Y %H:%M:%S")

                print(f"""{e.text} 
                Rate in question: {rate_limit_exhausted(BEARER_TOKEN)} 
                Waiting {minutes_to_wait} minutes before retrying ({time_to_resume})""")
                sleep(seconds_to_wait)
                continue
    
        #IF THERE ARE PAGEING TOKENS:
        if any(t in json_response['meta'] for t in tokens):
            try:
                json_response_gross.update(json_response['data'])
            except:
                json_response_gross.update(json_response)
            print(f'GET request succesfull ({i}/x): {url}')            
            if 'next_token' not in json_response['meta']:
                break
            else:
                token = json_response['meta']['next_token']
                url = f"{url_input}&pagination_token={token}"
                i += 1
        #IF THERE ARE NO NEXT/PREVIOUS TOKENS RESULTS ARE ON ONE PAGE AND THE WHILE LOOP IS BROKEN.
        else:
            try:
                json_response_gross.update(json_response['data'])
            except:
                json_response_gross.update(json_response)
            print(f'GET request succesfull : {url}')
            break

    return json_response_gross

# %% [markdown]
# ### Return dictionary of a user's friends'/followings' metadata based on username

# %%
def find_following_of_user(username, BEARER_TOKEN, max_results = None):
    #auth
    headers = create_headers(BEARER_TOKEN)
    
    #find user 
    url_user_lookup = url_lookup_user(username)
    user = connect_to_endpoint(url_user_lookup, headers)
    user_id = user['data'][0]['id']
    
    #find followers
    url_following_call = url_get_following(user_id)
    
    return connect_to_endpoint_pagenation(url_following_call, BEARER_TOKEN, max_results)

# %% [markdown]
# ## Data Collection

# %%
def snowball(seed, depth, regex_pattern_filter = '(?i)Wind'):
    #initiate variables
    all_balls_list = []
    all_results = []
    current_ball_results = []
    
    #first ball is the seed, which is NOT filtered with regex pattern.
    current_ball = [seed]
    
    for depth_level in range(depth + 1):      
        for v,x in enumerate(current_ball):
            print(f'{v+1} out of {len(current_ball)} users.')
            try:
                json_response_list = find_following_of_user(x, BEARER_TOKEN, max_results=1000)['data']
                for y in json_response_list:
                    y['followed_by'] = x
                    y['ball_depth'] = depth_level
                    y['regex_pattern_filter_to_create_ball'] = regex_pattern_filter
            except:
                json_response_list = []
            
            #store results
            current_ball_results.extend(json_response_list)

        #store results
        all_results.extend(current_ball_results)
        all_balls_list.extend(current_ball)
        
        df_to_ball = pd.DataFrame(current_ball_results)
        current_ball = list(set(df_to_ball['username'].loc[(df_to_ball['description'].str.contains(regex_pattern_filter)) | 
                                                           (df_to_ball['username'].str.contains(regex_pattern_filter))]))
        current_ball = [x for x in current_ball if x not in all_balls_list]

    return all_results, all_balls_list

# %% [markdown]
# ### Script

# %%
all_results_dict, all_balls_list = snowball('windwatchorg',0,regex_pattern_filter = '(?i)Wind*')
df_results = pd.DataFrame(all_results_dict)
df_results.to_pickle('results')
print(f'Scraped the users that these users follows: {all_balls_list}')
# Out:
# 1 out of 1 users.
# GET request succesfull : https://api.twitter.com/2/users/19776476/following?max_results=1000&user.fields=public_metrics,location,description,verified
# Scraped the users that these users follows: ['windwatchorg']

# %% [markdown]
# ## Data handling

# %%
#### SEED IS WINDWATCHORG

df_results = pd.concat([df_results,df_results['public_metrics'].apply(pd.Series)], axis=1)

# %% [markdown]
# ### Create a map

# %%
def gps_of_location(location):
    google_API_key = "AIzaSyBn6H0mv0o04Nr6gNF4rhj19G2PBEiaUB0"
    url = f"https://maps.googleapis.com/maps/api/geocode/json?address={location}&key={google_API_key}"
    json_response = connect_to_endpoint(url)
    if json_response['status'] == 'OK':
        d = json_response['results'][0]['geometry']['location']
        d['types_google_api_response'] = json_response['results'][0]['types']
        return d
    else:
        return 'No GPS coordinates found'

# %%
locations = df_results['location'].unique()

# %%
#### DON'T JUST RUN THIS CODE <3<3<3<3<3<3<3<3<3 Google API free tier is limited 
gps = {x : gps_of_location(x) for x in locations}

# %%
df_gps = pd.DataFrame(gps).transpose()
df = pd.merge(df_results,df_gps, left_on = 'location', right_index = True)

# %%
fig = px.scatter_geo(df_results,lat=df['lat'], lon=df['lng'],hover_name = df['username'])
fig.show()

# %% [markdown]
# ## Fooling around

# %%
gps_of_location('Blog')

# %%
gps_of_location('copenhagen')

# %%
gps_of_location('Frøya, Norge')

# %%
locations

# %%
gps_of_location('aasdasd is a place')

# %%
df

# %%
gps_of_location_dev('blog')

# %%
df

# %%
df_first_ball['location'].unique()

# %%
gps_of_location_dev('worldwide')

# %%
find_following_of_user('stopthesethings')

# %%
a = find_following_of_user('windwatchorg', BEARER_TOKEN, 1000)

# %%
b = pd.concat([pd.DataFrame(a['data']),pd.DataFrame(a['data'])['public_metrics'].apply(pd.Series).apply(pd.Series)], axis = 1)

# %%
b.sort_values('followers_count').tail(40)

# %%
a = find_following_of_user('MaryKayBarton',BEARER_TOKEN,1000)
# Out:
# This is the value of i = 1
# GET request succesfull (1/2): https://api.twitter.com/2/users/485717967/following?max_results=1000&user.fields=public_metrics,location,description,verified
# This is the value of i = 2
# GET request succesfull (2/1): https://api.twitter.com/2/users/485717967/following?max_results=1000&user.fields=public_metrics,location,description,verified&pagination_token=7JVQ0P32ESL1CZZZ
# This is the value of i = 3
# GET request succesfull (3/1): https://api.twitter.com/2/users/485717967/following?max_results=1000&user.fields=public_metrics,location,description,verified&pagination_token=BHIH794GOP518ZZZ
# This is the value of i = 4
# GET request succesfull (4/3): https://api.twitter.com/2/users/485717967/following?max_results=1000&user.fields=public_metrics,location,description,verified&pagination_token=MJ2VSAUJAUT16ZZZ
# While loop done!

# %%
a
# Out:
# {'data': [{'public_metrics': {'followers_count': 6878,
#     'following_count': 7523,
#     'tweet_count': 23618,
#     'listed_count': 2},
#    'id': '1300313886697152512',
#    'description': 'Proud & Deplorable. End the Lockdowns. Resist The Great Reset. IFBAP. Donald Trump WON and 46 can kiss💋my ass 🇺🇸',
#    'name': 'WE🇺🇸ARE🇺🇸MAGA',
#    'verified': False,
#    'username': 'WeAreMAGA'},
#   {'public_metrics': {'followers_count': 298,
#     'following_count': 958,
#     'tweet_count': 2893,
#     'listed_count': 2},
#    'id': '764964662781829121',
#    'description': 'Once a pharmacist Now full-time mom, content creator & occasional blogger https://t.co/VQl8Djgbtj one of my babies #MAGA "cause the world needs a strong America',
#    'name': 'Freedom Lover',
#    'location': 'Canada',
#    'verified': False,
#    'username': 'RealMe4Freedom'},
#   {'public_metrics': {'followers_count': 52245,
#     'following_count': 3974,
#     'tweet_count': 27678,
#     'listed_count': 480},
#    'id': '15719232',
#    'description': 'Senior Editor @EpochTimes👉https://t.co/7ztUYGbaYl; Host @AmThoughtLeader; 🎬 https://t.co/Kaf9ohTLbz; Subscribe: https://t.co/ayj0kiHsjQ; American exceptionalist Canadian 🇨🇦🇺🇸🇭🇰🇹🇼',
#    'name': 'Jan Jekielek',
#    'location': 'New York, New York',
#    'verified': False,
#    'username': 'JanJekielek'},
#   {'public_metrics': {'followers_count': 54881,
#     'following_count': 1752,
#     'tweet_count': 8841,
#     'listed_count': 332},
#    'id': '89083397',
#    'description': 'Senior investigative reporter @EpochTimes and host of @Crossroads_josh. Writing on subversion, unrestricted warfare, and Chinese espionage. All tweets my own.',
#    'name': 'Joshua Philipp',
#    'location': 'New York City',
#    'verified': False,
#    'username': 'JoshJPhilipp'},
#   {'public_metrics': {'followers_count': 1994,
#     'following_count': 2505,
#     'tweet_count': 436,
#     'listed_count': 19},
#    'id': '534789796',
#    'description': 'Retired military, father, husband, defender of the Constitution and proud American.',
#    'name': 'ConcrndCtzn0171',
#    'verified': False,
#    'username': 'ConcrndCtzn0171'},
#   {'public_metrics': {'followers_count': 3440,
#     'following_count': 24,
#     'tweet_count': 13084,
#     'listed_count': 49},
#    'id': '4418790390',
#    'description': '"Who controls the funding controls the science."\n\nFollow for Natural Climate Truth\n\nAlso at:\nhttps://t.co/bMR8towP1z\nhttps://t.co/Inn0pY17Wm',
#    'name': '💥 ClimatePoet 💥',
#    'verified': False,
#    'username': 'ClimatePoet'},
#   {'public_metrics': {'followers_count': 99880,
#     'following_count': 123,
#     'tweet_count': 1918,
#     'listed_count': 1098},
#    'id': '4826563611',
#    'description': 'Independent news and investigative journalism on empire || En español: @GrayzoneES || "Deeply disturbing" -US Rep. Michael McCaul',
#    'name': 'The Grayzone',
#    'verified': False,
#    'username': 'TheGrayzoneNews'},
#   {'public_metrics': {'followers_count': 6507,
#     'following_count': 999,
#     'tweet_count': 23013,
#     'listed_count': 177},
#    'id': '93684678',
#    'description': 'Capitol reporter at City & State NY | 中文 | RT/likes ≠ anything',
#    'name': 'Zach Williams',
#    'location': 'Albany, NY',
#    'verified': False,
#    'username': 'ZachReports'},
#   {'public_metrics': {'followers_count': 955,
#     'following_count': 675,
#     'tweet_count': 2888,
#     'listed_count': 31},
#    'id': '1510951723',
#    'description': 'Editor, California Energy Markets; Host, "Substation California" Podcast; Consultant; Privacy Advocate; Sierra Nevada Dweller; 2-Wheel Fan. Opinions=my own.',
#    'name': 'Jason Fordney',
#    'location': 'Grass Valley, CA',
#    'verified': False,
#    'username': 'FordneyEnergy'},
#   {'public_metrics': {'followers_count': 14,
#     'following_count': 56,
#     'tweet_count': 100,
#     'listed_count': 0},
#    'id': '967736032044175361',
#    'description': 'Twenty-Five years – a huge career accomplishment, especially in the music business. Aaron Tippin – who marks his silver anniversary as a recording artist 2015',
#    'name': 'Aaron Tippin',
#    'verified': False,
#    'username': 'AaronTippin7'},
#   {'public_metrics': {'followers_count': 3444,
#     'following_count': 30,
#     'tweet_count': 294,
#     'listed_count': 64},
#    'id': '288461644',
#    'description': "Don't miss any updates from Larry Kudlow’s Radio Show. Follow us here to see the latest tweets from the radio studio! (Tweets here from radio show producers.)",
#    'name': 'Larry Kudlow Show',
#    'location': 'WABC Radio Studio - NYC',
#    'verified': False,
#    'username': 'LarryKudlowShow'},
#   {'public_metrics': {'followers_count': 1023,
#     'following_count': 1400,
#     'tweet_count': 25722,
#     'listed_count': 20},
#    'id': '269588941',
#    'description': 'The truth is...I am Iron Man #Kamala202X',
#    'name': '🐊🌐Alli Gator @🏡',
#    'location': 'Madison, WI',
#    'verified': False,
#    'username': 'PoliticalPup415'},
#   {'public_metrics': {'followers_count': 207432,
#     'following_count': 2588,
#     'tweet_count': 27251,
#     'listed_count': 513},
#    'id': '63769373',
#    'description': 'GRAMMY award-winning Singer, Songwriter, Musician & Multi-Platinum Recording Artist. SET IN STONE is OUT NOW! Stream it and save it on your favorite platform.',
#    'name': 'Travis Tritt',
#    'location': 'Hiram, Georgia',
#    'verified': True,
#    'username': 'Travistritt'},
#   {'public_metrics': {'followers_count': 784,
#     'following_count': 135,
#     'tweet_count': 3214,
#     'listed_count': 28},
#    'id': '1233204824008585217',
#    'description': 'Retired Rocket Scientist 🚀-CANSLIM Investor,President R6 Investment Group.📈 @IBDinvestors,@AAII_Invest_Ed\nAll opinions are my own and not investment advice.',
#    'name': 'Jim Robinson (GJ)',
#    'location': 'Alpine Utah',
#    'verified': False,
#    'username': 'rubinj57'},
#   {'public_metrics': {'followers_count': 142,
#     'following_count': 336,
#     'tweet_count': 2221,
#     'listed_count': 2},
#    'id': '28741869',
#    'description': 'Student of the Markets, Can Slim, Student of Life, Intuitive Healer, Personal Transformation Coach, Self Improvement Junkie',
#    'name': 'Shari Gordon',
#    'location': 'Lakewood, CO',
#    'verified': False,
#    'username': 'sharigordon'},
#   {'public_metrics': {'followers_count': 449,
#     'following_count': 528,
#     'tweet_count': 90746,
#     'listed_count': 6},
#    'id': '1066737044326625281',
#    'description': '',
#    'name': 'Nick Kola',
#    'verified': False,
#    'username': 'kola_nick'},
#   {'public_metrics': {'followers_count': 1303,
#     'following_count': 2798,
#     'tweet_count': 5612,
#     'listed_count': 58},
#    'id': '85438654',
#    'description': 'Founder of Energy Reality Project which has a mandate to raise awareness  & educate people about the need for nuclear energy. #U2BP Unashamed to Be Pro-nuclear',
#    'name': 'Rick Maltese',
#    'location': 'Toronto, Ontario, Canada',
#    'verified': False,
#    'username': 'pronuclear'},
#   {'public_metrics': {'followers_count': 509234,
#     'following_count': 7640,
#     'tweet_count': 4820,
#     'listed_count': 3318},
#    'id': '14433891',
#    'description': 'Follower of Jesus, husband, father, recording artist. Check out "The Worship Project" and my latest release, "Out of my Hands" now!',
#    'name': 'Jeremy Camp',
#    'location': 'Nashville, TN',
#    'verified': True,
#    'username': 'jeremycamp'},
#   {'public_metrics': {'followers_count': 178452,
#     'following_count': 657,
#     'tweet_count': 25716,
#     'listed_count': 2610},
#    'id': '14869587',
#    'description': 'President @SBTS, President Evangelical Theological Society, Centennial Professor of Christian Theology, author; broadcaster; theologian',
#    'name': 'Albert Mohler',
#    'location': 'Louisville, KY',
#    'verified': True,
#    'username': 'albertmohler'},
#   {'public_metrics': {'followers_count': 72804,
#     'following_count': 51983,
#     'tweet_count': 49482,
#     'listed_count': 1271},
#    'id': '39288218',
#    'description': 'Your bridge to the persecuted Church. RT/following ≠ endorsement',
#    'name': 'International Christian Concern',
#    'location': 'Washington, D.C.',
#    'verified': False,
#    'username': 'persecutionnews'},
#   {'public_metrics': {'followers_count': 4941,
#     'following_count': 3181,
#     'tweet_count': 5634,
#     'listed_count': 16},
#    'id': '1212749913399808003',
#    'description': 'Nationalist. Writer for @Breaking911.',
#    'name': 'Izzy',
#    'location': 'USA',
#    'verified': False,
#    'username': 'B911Izzy'},
#   {'public_metrics': {'followers_count': 124293,
#     'following_count': 337,
#     'tweet_count': 61890,
#     'listed_count': 1122},
#    'id': '119837703',
#    'description': 'Investigative reporter at The Washington Free Beacon. Previously: The Daily Caller. Email tips securely to chuck.ross@protonmail.com',
#    'name': 'Chuck Ross',
#    'verified': True,
#    'username': 'ChuckRossDC'},
#   {'public_metrics': {'followers_count': 22870,
#     'following_count': 22525,
#     'tweet_count': 297328,
#     'listed_count': 181},
#    'id': '556118417',
#    'description': 'Big fan of political skirmishes, college football, slow-cooked BBQ and lip gloss that stays on for more than 20 minutes. Plz follow @OKGretchen, too.',
#    'name': 'GretchenInOK',
#    'location': 'Oklahoma, USA',
#    'verified': False,
#    'username': 'GretchenInOK'},
#   {'public_metrics': {'followers_count': 528,
#     'following_count': 4989,
#     'tweet_count': 3245,
#     'listed_count': 1},
#    'id': '1250469441760112640',
#    'description': 'A special limited edition commemorative book celebrating the achievements of President Donald J. Trump 🇺🇸 Available on Amazon and our official website.',
#    'name': 'Celebrating the President',
#    'verified': False,
#    'username': 'CelebratingDJT'},
#   {'public_metrics': {'followers_count': 83823,
#     'following_count': 4109,
#     'tweet_count': 5187,
#     'listed_count': 955},
#    'id': '2975091705',
#    'description': "Proudly serving Georgia's 10th District | @FreedomCaucus Communications Chair | @GOPOversight Government Operations Subcommittee Ranking Member",
#    'name': 'Rep. Jody Hice',
#    'location': 'Greensboro, GA; Washington, DC',
#    'verified': True,
#    'username': 'CongressmanHice'},
#   {'public_metrics': {'followers_count': 38175,
#     'following_count': 617,
#     'tweet_count': 3093,
#     'listed_count': 632},
#    'id': '817138492614524928',
#    'description': 'Proudly serving the 13th district of North Carolina. Instagram: reptedbudd',
#    'name': 'Congressman Ted Budd',
#    'location': 'Davie County, North Carolina',
#    'verified': True,
#    'username': 'RepTedBudd'},
#   {'public_metrics': {'followers_count': 38696,
#     'following_count': 47,
#     'tweet_count': 3487,
#     'listed_count': 544},
#    'id': '1082790600292925440',
#    'description': "Congressman Roy's personal suspension of social media continues. This is a staff account to provide updates to our constituents in Texas' 21st District.",
#    'name': 'Rep. Chip Roy Press Office',
#    'location': 'Washington, DC',
#    'verified': True,
#    'username': 'RepChipRoy'},
#   {'public_metrics': {'followers_count': 149004,
#     'following_count': 830,
#     'tweet_count': 7874,
#     'listed_count': 883},
#    'id': '3066800573',
#    'description': 'Writer, filmmaker, rabble-rouser. Senior fellow, @ManhattanInst. Married to @skprufo. Watch my new film for free: https://t.co/tx3e2oaYMD.',
#    'name': 'Christopher F. Rufo ⚔️',
#    'location': 'Pacific Northwest',
#    'verified': False,
#    'username': 'realchrisrufo'},
#   {'public_metrics': {'followers_count': 5770,
#     'following_count': 2953,
#     'tweet_count': 12912,
#     'listed_count': 23},
#    'id': '752077698',
#    'description': 'Father of 4 | Host of #FirstClassFatherhood | Interviews with Dads such as Matthew McConaughey, Dana White, Tony Hawk, Deion Sanders, Tom Brady + more',
#    'name': 'First Class Fatherhood 🎙',
#    'location': 'United States',
#    'verified': False,
#    'username': 'AlecLace'},
#   {'public_metrics': {'followers_count': 259,
#     'following_count': 999,
#     'tweet_count': 6395,
#     'listed_count': 7},
#    'id': '310638676',
#    'description': 'Christian, Conservative, Military Intelligence, Trust Officer, Banker, BSA, NRA, Pro Education, Concerned about Government Tyranny, Patriot!',
#    'name': 'John Mays',
#    'verified': False,
#    'username': 'windwood1790'},
#   {'public_metrics': {'followers_count': 77900,
#     'following_count': 5408,
#     'tweet_count': 64959,
#     'listed_count': 1031},
#    'id': '8349572',
#    'description': 'Unraveling fears one chart at a time // mktg + AI + crypto // data, demographics, and steaks. justinhart.biz@gmail.com // claimed by @jennyerikson. Father to 8!',
#    'name': 'Justin Hart',
#    'location': 'San Diego, CA',
#    'verified': False,
#    'username': 'justin_hart'},
#   {'public_metrics': {'followers_count': 18,
#     'following_count': 5,
#     'tweet_count': 932,
#     'listed_count': 0},
#    'id': '3191044472',
#    'description': 'Beware of greenwashed industrialization and rebranded growthism.',
#    'name': 'False Progress',
#    'location': 'USA',
#    'verified': False,
#    'username': 'FiniteEarther'},
#   {'public_metrics': {'followers_count': 20554,
#     'following_count': 12911,
#     'tweet_count': 9442,
#     'listed_count': 90},
#    'id': '42158021',
#    'description': 'Father First 🙋🏼\u200d♂️Family Man  👸🏼 @beccathorderson 🔥 Vice President @todayisamerica  Ambassador @turningpointusa  Entrepreneur 💰💰',
#    'name': 'Gunnar Thorderson',
#    'location': 'Insta: gunnarthorderson',
#    'verified': False,
#    'username': 'Gunnar_Thor'},
#   {'public_metrics': {'followers_count': 537,
#     'following_count': 851,
#     'tweet_count': 8311,
#     'listed_count': 18},
#    'id': '877130642',
#    'description': 'All about Dakota - both North and South. Political junkie, climate realist, former journalist, master gardener, decent bowler, competent golfer.',
#    'name': 'Geoff Simon',
#    'verified': False,
#    'username': 'GeoffSimonSays'},
#   {'public_metrics': {'followers_count': 103,
#     'following_count': 263,
#     'tweet_count': 6203,
#     'listed_count': 2},
#    'id': '492332595',
#    'description': 'Born-again ✝️, husband, dad, Gideon, car guy, ⚾️ fanatic.\n\nUse your real name or talk to the hand. Also, #blameAmendmentXIX & #NoTimeForTrolls',
#    'name': '𝐑𝐢𝐜𝐡 𝐑𝐚𝐮𝐜𝐡 ✝️🇺🇸⚾️🇮🇱',
#    'location': 'Iowa, USA',
#    'verified': False,
#    'username': 'RichRauch'},
#   {'public_metrics': {'followers_count': 390,
#     'following_count': 1427,
#     'tweet_count': 436,
#     'listed_count': 3},
#    'id': '849290534132879360',
#    'description': 'Husband, father, product of FoMo, CSM grad, proud member of the oil & gas industry. Important to me: Grace. Truth. Transparency. Accountability. Liberty.',
#    'name': 'Ryan Zorn',
#    'location': 'Denver, CO',
#    'verified': False,
#    'username': 'ryanzornCO'},
#   {'public_metrics': {'followers_count': 102,
#     'following_count': 657,
#     'tweet_count': 4375,
#     'listed_count': 6},
#    'id': '365208273',
#    'description': '',
#    'name': 'Richard Windsor',
#    'location': 'Flyover State',
#    'verified': False,
#    'username': 'lrlodes'},
#   {'public_metrics': {'followers_count': 430,
#     'following_count': 710,
#     'tweet_count': 7867,
#     'listed_count': 32},
#    'id': '2877532224',
#    'description': 'filia luminis. The truth will set you free.  https://t.co/bEVgtWZSCy #RadioTheWayItShouldBe\nCatholic. Wife. Mom. ER Nurse (BSN,RN,CEN)',
#    'name': 'Mittus Peppe[r]',
#    'verified': False,
#    'username': 'PepperDulce'},
#   {'public_metrics': {'followers_count': 385598,
#     'following_count': 1086,
#     'tweet_count': 3233,
#     'listed_count': 1069},
#    'id': '487297085',
#    'description': "Florida's 46th Governor. Iraq Veteran. Native Floridian. Fighting for Good Jobs, Better Schools, Clean Water, and Safe Communities.",
#    'name': 'Ron DeSantis',
#    'location': 'Florida',
#    'verified': True,
#    'username': 'RonDeSantisFL'},
#   {'public_metrics': {'followers_count': 73486,
#     'following_count': 518,
#     'tweet_count': 94790,
#     'listed_count': 967},
#    'id': '775175696645623808',
#    'description': 'Keynote Speaker and Woodworker.  \nEverything Energy\n|English/Arabic Tweets|\nPeople can make the story they want out of actual numbers!',
#    'name': 'Anas Alhajji',
#    'location': 'Dallas, USA',
#    'verified': True,
#    'username': 'anasalhajji'},
#   {'public_metrics': {'followers_count': 55474,
#     'following_count': 1818,
#     'tweet_count': 87063,
#     'listed_count': 594},
#    'id': '17847906',
#    'description': 'Born USSR | raised Brooklyn. Columnist @nypost, Contributor @SpectatorUSA, Contributing Writer @dcexaminer magazine.',
#    'name': 'Karol Markowicz',
#    'location': 'BK all day',
#    'verified': True,
#    'username': 'karol'},
#   {'public_metrics': {'followers_count': 1928,
#     'following_count': 2,
#     'tweet_count': 90,
#     'listed_count': 11},
#    'id': '1351941454223040519',
#    'description': 'For God. For Country. For Community.\nPresident @russvought',
#    'name': 'Center for Renewing America',
#    'location': 'Washington, D.C. ',
#    'verified': False,
#    'username': 'amrenewctr'},
#   {'public_metrics': {'followers_count': 5371,
#     'following_count': 1654,
#     'tweet_count': 1056,
#     'listed_count': 81},
#    'id': '121147627',
#    'description': 'President, Center for Renewing America: @AmRenewCtr | Former Trump Cabinet, OMB Director | Husband: @MaryVought | Dad | Ephesians 2:4-5, "But God."',
#    'name': 'Russ Vought',
#    'verified': False,
#    'username': 'russvought'},
#   {'public_metrics': {'followers_count': 17001,
#     'following_count': 4114,
#     'tweet_count': 18560,
#     'listed_count': 257},
#    'id': '33402633',
#    'description': "Florida's Chief Financial Officer & State Fire Marshal. Working to make sure all families can succeed here in #Florida! Most importantly, husband + dad of 2!",
#    'name': 'Jimmy Patronis',
#    'location': 'Florida, USA',
#    'verified': True,
#    'username': 'JimmyPatronis'},
#   {'public_metrics': {'followers_count': 55157,
#     'following_count': 2816,
#     'tweet_count': 4272,
#     'listed_count': 402},
#    'id': '3231657095',
#    'description': 'Candidate for U.S. Congress (FL-11) | State Representative (FL-32) | Veteran | Attorney | UF: BA ‘12 JD ‘17 | #AmericaFirst',
#    'name': 'Rep. Anthony Sabatini',
#    'location': 'Lake County, FL',
#    'verified': True,
#    'username': 'AnthonySabatini'},
#   {'public_metrics': {'followers_count': 48863,
#     'following_count': 457,
#     'tweet_count': 13258,
#     'listed_count': 282},
#    'id': '21837858',
#    'description': 'Husband, father, recording artist, author founder of multiple movements, lover of Jesus Christ.',
#    'name': 'Sean Feucht',
#    'location': 'California, USA',
#    'verified': False,
#    'username': 'seanfeucht'},
#   {'public_metrics': {'followers_count': 410470,
#     'following_count': 243,
#     'tweet_count': 2374,
#     'listed_count': 3763},
#    'id': '18253799',
#    'description': "I'm only dirty on the outside.",
#    'name': 'The Real Mike Rowe',
#    'location': 'http://mikerowe.com/podcast/',
#    'verified': True,
#    'username': 'mikeroweworks'},
#   {'public_metrics': {'followers_count': 2979,
#     'following_count': 4238,
#     'tweet_count': 48641,
#     'listed_count': 42},
#    'id': '2206097024',
#    'description': 'See my facebook and twitter many import. articles,videos & comments related to what I discuss in my book.Americans Held Hostage by the Environmentalist Movement',
#    'name': 'Bruce Schlink',
#    'verified': False,
#    'username': 'bruce_schlink'},
#   {'public_metrics': {'followers_count': 1024214,
#     'following_count': 606,
#     'tweet_count': 6573,
#     'listed_count': 2180},
#    'id': '47293791',
#    'description': 'Actor• Comedian•Commentator• My new book "From The Foster House To The White House" is available @ https://t.co/bgO7kKUl3H',
#    'name': 'Terrence K. Williams',
#    'location': 'United States',
#    'verified': True,
#    'username': 'w_terrence'},
#   {'public_metrics': {'followers_count': 231,
#     'following_count': 122,
#     'tweet_count': 38712,
#     'listed_count': 11},
#    'id': '4262976553',
#    'description': 'America First Politically Incorrect',
#    'name': 'Jim Fisher',
#    'location': 'Minnesota',
#    'verified': False,
#    'username': 'JimFish56837379'},
#   {'public_metrics': {'followers_count': 1,
#     'following_count': 6,
#     'tweet_count': 15,
#     'listed_count': 0},
#    'id': '1079143122234421254',
#    'description': '',
#    'name': 'Jeremy Collins',
#    'verified': False,
#    'username': 'JeremyC70492785'},
#   {'public_metrics': {'followers_count': 5,
#     'following_count': 46,
#     'tweet_count': 447,
#     'listed_count': 0},
#    'id': '846686663443185664',
#    'description': 'Just an old Fire Chief who loves this Country.',
#    'name': 'Ken',
#    'location': 'Virginia, USA',
#    'verified': False,
#    'username': 'Chiefstr13Ken'},
#   {'public_metrics': {'followers_count': 21,
#     'following_count': 363,
#     'tweet_count': 148,
#     'listed_count': 0},
#    'id': '44920015',
#    'description': 'Patriot, NY Police Lieutenant, attorney and Criminal Law Professor and proud American.',
#    'name': 'W D',
#    'location': 'Nassau County, NY',
#    'verified': False,
#    'username': 'WADESQ'},
#   {'public_metrics': {'followers_count': 4137,
#     'following_count': 3963,
#     'tweet_count': 48688,
#     'listed_count': 101},
#    'id': '797981',
#    'description': "There's not enough time to enjoy aviation, cars, family, friends, gadgets, hobbies, travel or to go sailing. Saved by Grace (Eph.2:8)",
#    'name': 'Rich Corbett  🇺🇸',
#    'location': 'Cincinnati OH',
#    'verified': False,
#    'username': 'RichC'},
#   {'public_metrics': {'followers_count': 145294,
#     'following_count': 597,
#     'tweet_count': 12545,
#     'listed_count': 626},
#    'id': '85985754',
#    'description': '📺Fox News Channel. Believer. Capitalist. Texan. Libertarian. Storyteller. Proverbs 28:1 🦁. Liberty and justice for all.',
#    'name': 'Lawrence B. Jones III',
#    'location': 'Dallas/NYC',
#    'verified': True,
#    'username': 'LawrenceBJones3'},
#   {'public_metrics': {'followers_count': 188849,
#     'following_count': 6620,
#     'tweet_count': 21434,
#     'listed_count': 610},
#    'id': '2471692340',
#    'description': 'Pastor, New Spirit Revival Center; CEO WCCD Radio; Ceo National Diversity Coalition for Trump; CEO Urban Revitalization Coalition; Presidential Transition Team',
#    'name': 'Dr.Darrell Scott',
#    'location': 'Ohio',
#    'verified': True,
#    'username': 'PastorDScott'},
#   {'public_metrics': {'followers_count': 73126,
#     'following_count': 1807,
#     'tweet_count': 16092,
#     'listed_count': 213},
#    'id': '78685709',
#    'description': 'Slave of Christ Jesus • Evangelist • Presidential Appointee • Chairman, AFPI Opportunity Now • 3x @NFL Team Captain • Philanthropist • Youth Coach • Proud Papa',
#    'name': 'Jack Brewer',
#    'location': '#GloryToGod',
#    'verified': True,
#    'username': 'JackBrewerBSI'},
#   {'public_metrics': {'followers_count': 8569,
#     'following_count': 9361,
#     'tweet_count': 164001,
#     'listed_count': 126},
#    'id': '49102516',
#    'description': 'retired us army vet, Christian conservative followed by a lot of patriots',
#    'name': 'jimmylemons',
#    'location': 'ROSELAND NJ',
#    'verified': False,
#    'username': 'jimmylemons'},
#   {'public_metrics': {'followers_count': 86368,
#     'following_count': 5152,
#     'tweet_count': 51574,
#     'listed_count': 2234},
#    'id': '34371118',
#    'description': 'Columnist for @Bopinion. National Security Journalism Fellow at @ClementCenter Read my longer stuff at @commentary and @readliberties',
#    'name': 'Eli Lake',
#    'location': 'District of Columbia',
#    'verified': True,
#    'username': 'EliLake'},
#   {'public_metrics': {'followers_count': 2507728,
#     'following_count': 1320,
#     'tweet_count': 86565,
#     'listed_count': 6645},
#    'id': '43775786',
#    'description': 'El Presidente/3 time Bee Sting survivor. I own a ton of Penn Stock. I’m not a financial advisor. Don’t trust anything I say about stocks. Owner of DDTG Global',
#    'name': 'Dave Portnoy',
#    'location': 'Boston',
#    'verified': False,
#    'username': 'stoolpresidente'},
#   {'public_metrics': {'followers_count': 2861094,
#     'following_count': 757,
#     'tweet_count': 45339,
#     'listed_count': 5275},
#    'id': '22637974',
#    'description': 'Viva La Stool - Download the Barstool Sports app https://t.co/sxfRMbcsSw',
#    'name': 'Barstool Sports',
#    'location': 'America',
#    'verified': True,
#    'username': 'barstoolsports'},
#   {'public_metrics': {'followers_count': 1101583,
#     'following_count': 2591,
#     'tweet_count': 10774,
#     'listed_count': 5195},
#    'id': '26637348',
#    'description': '2020 Presidential candidate & former Congresswoman - HI. Veteran. Soldier. Surfer. Yoga. Plant-based. Podcast coming soon! Inquiries: https://t.co/PI1sHr5MBb',
#    'name': 'Tulsi Gabbard 🌺',
#    'location': "Hawai'i",
#    'verified': True,
#    'username': 'TulsiGabbard'},
#   {'public_metrics': {'followers_count': 38237,
#     'following_count': 623,
#     'tweet_count': 2130,
#     'listed_count': 92},
#    'id': '2413289725',
#    'description': 'Physician. Plant Based. Wifey. Pro-Life. Johns Hopkins trained. Healthcare is a Swamp!! Follow me on Instagram, Parler, Gab also @RupaliChadhaMD',
#    'name': 'Rupali Chadha, M.D.🩺',
#    'verified': False,
#    'username': 'RupaliChadhaMD'},
#   {'public_metrics': {'followers_count': 14925,
#     'following_count': 997,
#     'tweet_count': 47874,
#     'listed_count': 119},
#    'id': '25409870',
#    'description': 'Writer l Words: @FDRLST, @resurgent, @TheFirstonTV l Adjunct Instructor l My book baby DEAR MISS MOREAU is on Amazon l Ramblings:  https://t.co/IzZElkDXIH',
#    'name': 'Anna James Zeigler',
#    'location': 'Louisiana',
#    'verified': False,
#    'username': 'ajzeigler'},
#   {'public_metrics': {'followers_count': 186000,
#     'following_count': 418,
#     'tweet_count': 18342,
#     'listed_count': 495},
#    'id': '110542860',
#    'description': 'Iraq Vet. Sr. Contributor @TPUSA. 📺@TheFirstOnTV. Author: Always a Soldier. Host/EP: Rob Smith Is Problematic. Download and Subscribe👇🏿',
#    'name': 'Rob Smith 🇺🇸',
#    'location': 'NYC/FL',
#    'verified': False,
#    'username': 'robsmithonline'},
#   {'public_metrics': {'followers_count': 87612,
#     'following_count': 1131,
#     'tweet_count': 46356,
#     'listed_count': 638},
#    'id': '66923871',
#    'description': '@GOP National Spokesperson & Director of Black Media Affairs | Former @POTUS45 WH Fellowships Commissioner & GW Bush White House staff | @peppalum 🇺🇸',
#    'name': 'PARIS',
#    'location': 'Washington DC',
#    'verified': True,
#    'username': 'PARISDENNARD'},
#   {'public_metrics': {'followers_count': 50740,
#     'following_count': 504,
#     'tweet_count': 6462,
#     'listed_count': 314},
#    'id': '488950348',
#    'description': 'Father, physician, public health advocate. Former IN Health Commissioner/ Associate Professor of Anesthesia/ 20th US Surgeon General',
#    'name': 'Jerome Adams',
#    'location': 'Indianapolis, IN',
#    'verified': True,
#    'username': 'JeromeAdamsMD'},
#   {'public_metrics': {'followers_count': 1047305,
#     'following_count': 266,
#     'tweet_count': 653,
#     'listed_count': 2031},
#    'id': '1163992520252153857',
#    'description': 'Former U.S. Secretary of State, Director of the CIA, Congressman. Christian, husband, father, Army veteran, Kansan and proud American 🇺🇸',
#    'name': 'Mike Pompeo',
#    'verified': True,
#    'username': 'mikepompeo'},
#   {'public_metrics': {'followers_count': 580005,
#     'following_count': 428,
#     'tweet_count': 1863,
#     'listed_count': 1742},
#    'id': '48143209',
#    'description': "Alan has sold nearly 60 million albums worldwide and has written or co-written 24 of his 35 #1s. He's an 18x ACM, 16x CMA, and a 2x Grammy-winning artist.",
#    'name': 'Alan Jackson',
#    'location': 'Nashville, TN',
#    'verified': True,
#    'username': 'OfficialJackson'},
#   {'public_metrics': {'followers_count': 2226,
#     'following_count': 291,
#     'tweet_count': 45725,
#     'listed_count': 193},
#    'id': '16689633',
#    'description': 'Time traveler from age of steam. Transcontinental train tracks to deep space orbits in less than 100 years. Nuclear energy, space, media.',
#    'name': 'Dan Yurman',
#    'location': 'Idaho Falls, ID; Cleveland, OH',
#    'verified': False,
#    'username': 'djysrv'},
#   {'public_metrics': {'followers_count': 63797,
#     'following_count': 274,
#     'tweet_count': 14483,
#     'listed_count': 617},
#    'id': '195874648',
#    'description': '🇲🇽 NASCAR Driver of the No. 99 Trackhouse Racing Chevy #SuarezNation #DanielsAmigos',
#    'name': 'Daniel Suárez',
#    'location': 'At the race track✌️',
#    'verified': True,
#    'username': 'Daniel_SuarezG'},
#   {'public_metrics': {'followers_count': 29668,
#     'following_count': 535,
#     'tweet_count': 6303,
#     'listed_count': 118},
#    'id': '19658895',
#    'description': 'Rome Correspondent, @EpochTimes; Host: @GRNonline; Contributor, @NCRegister Accredited to @HolySeePress. **Free Exchange Of Ideas** RTs ≠ Endorsements',
#    'name': 'Bree A Dail',
#    'location': 'Roma, Italia',
#    'verified': False,
#    'username': 'breeadail'},
#   {'public_metrics': {'followers_count': 43530,
#     'following_count': 40013,
#     'tweet_count': 63914,
#     'listed_count': 62},
#    'id': '993544147175952384',
#    'description': 'Retired US Army SFC and Combat Veteran of Desert Storm, Iraq and Afghanistan. Disabled Veteran #ElPaso',
#    'name': 'Samuel Williams',
#    'location': 'El Paso, TX',
#    'verified': True,
#    'username': 'votesamuelwill1'},
#   {'public_metrics': {'followers_count': 65842,
#     'following_count': 2514,
#     'tweet_count': 62380,
#     'listed_count': 286},
#    'id': '934049237628841984',
#    'description': 'I post short clips of important news so you don’t have to Watch the news all day. Things maybe spelled crazy but my hands don’t work and I use Siri to type.',
#    'name': 'The Dirty Truth (Josh)',
#    'location': 'West Virginia, USA',
#    'verified': False,
#    'username': 'AKA_RealDirty'},
#   {'public_metrics': {'followers_count': 40934,
#     'following_count': 1844,
#     'tweet_count': 192348,
#     'listed_count': 738},
#    'id': '31136822',
#    'description': 'Deputy Managing Editor, video creator at @RedState. I do bad photoshops and own dogs. Never tell me the odds. \n-Send hate mail to brandon@redstate.com',
#    'name': 'Brandon Morse',
#    'location': 'Dallas, TX',
#    'verified': True,
#    'username': 'TheBrandonMorse'},
#   {'public_metrics': {'followers_count': 209,
#     'following_count': 1562,
#     'tweet_count': 11107,
#     'listed_count': 0},
#    'id': '1270477668576886787',
#    'description': "Level headed realist. Anti War, Pro Evironment, Follow the information not ur emotions. Not Hate to disagree. Enlighten yourself as Yoda probably would've said.",
#    'name': 'Will Adams',
#    'location': 'UK/USA',
#    'verified': False,
#    'username': 'WillAdamslsd'},
#   {'public_metrics': {'followers_count': 1262,
#     'following_count': 1724,
#     'tweet_count': 12170,
#     'listed_count': 23},
#    'id': '516928956',
#    'description': 'Proud American,Navy submarine vet, seeker of truth, praying for Our country.',
#    'name': 'Mac_in_FL',
#    'location': 'Florida',
#    'verified': False,
#    'username': '_mcdowellb'},
#   {'public_metrics': {'followers_count': 6513,
#     'following_count': 6467,
#     'tweet_count': 134117,
#     'listed_count': 125},
#    'id': '38521282',
#    'description': "Christ-Follower, Wife, Mom, Educator, Conservative, Blogger @ Resplendent Daughter Ministries, Women's Ministry Speaker #ccot  #SoliDeoGloria #IStandWithIsrael",
#    'name': 'Gena Hood',
#    'location': 'Southeastern USA',
#    'verified': False,
#    'username': 'cantontweet'},
#   {'public_metrics': {'followers_count': 547914,
#     'following_count': 395,
#     'tweet_count': 19004,
#     'listed_count': 1541},
#    'id': '4041824789',
#    'description': 'Right Side Broadcasting Network, Auburn AL. Telegram: @RSBNetwork  CEO @JoeSeales Telegram: https://t.co/wIDS7wCGIi',
#    'name': 'RSBN 🇺🇸',
#    'location': 'Auburn, AL',
#    'verified': True,
#    'username': 'RSBNetwork'},
#   {'public_metrics': {'followers_count': 168128,
#     'following_count': 166,
#     'tweet_count': 1723,
#     'listed_count': 443},
#    'id': '3740820863',
#    'description': 'Ret Lt Firefighter/Christian/Author -The Trump Prophecies/ Prophecies at https://t.co/WBAfYtxGqJ Inventor of the SORD and SOS Tools. https://t.co/8ptuRMlKL4 ...-',
#    'name': 'Mark Taylor',
#    'verified': False,
#    'username': 'patton6966'},
#   {'public_metrics': {'followers_count': 99532,
#     'following_count': 1021,
#     'tweet_count': 8368,
#     'listed_count': 402},
#    'id': '499154896',
#    'description': 'CEO of @XStrategiesLLC | Advisor to Conservative Politicians, Public Figures, and Organizations',
#    'name': 'Alex Bruesewitz',
#    'location': 'WI | FL | DC',
#    'verified': False,
#    'username': 'alexbruesewitz'},
#   {'public_metrics': {'followers_count': 253441,
#     'following_count': 84,
#     'tweet_count': 457,
#     'listed_count': 807},
#    'id': '806344552718045184',
#    'description': 'Doctor • Lawyer • Warrior 🥼 Founder of https://t.co/5BP4zHiApV',
#    'name': 'Dr. Simone Gold',
#    'location': 'Los Angeles, CA',
#    'verified': False,
#    'username': 'drsimonegold'},
#   {'public_metrics': {'followers_count': 17077,
#     'following_count': 495,
#     'tweet_count': 987,
#     'listed_count': 435},
#    'id': '1028854804087492613',
#    'description': "Congressman representing Tennessee's 2nd District. Husband to Kelly. Father to Isabel. Serve on Transportation & Infrastructure and Foreign Affairs committees",
#    'name': 'Rep. Tim Burchett',
#    'location': 'East Tennessee',
#    'verified': True,
#    'username': 'RepTimBurchett'},
#   {'public_metrics': {'followers_count': 28,
#     'following_count': 3,
#     'tweet_count': 28,
#     'listed_count': 0},
#    'id': '1285725067163443201',
#    'description': 'Co-Chair Wildlife, Energy & Community Coalition, Director Windaction Group. Advocate for communities, wildlife facing large-scale renewable development.',
#    'name': 'Lisa Linowes',
#    'verified': False,
#    'username': 'LinowesLisa'},
#   {'public_metrics': {'followers_count': 205587,
#     'following_count': 378,
#     'tweet_count': 559,
#     'listed_count': 450},
#    'id': '197974180',
#    'description': '#BillsMafia',
#    'name': 'Josh Allen',
#    'location': '7220',
#    'verified': True,
#    'username': 'JoshAllenQB'},
#   {'public_metrics': {'followers_count': 925,
#     'following_count': 1124,
#     'tweet_count': 188,
#     'listed_count': 2},
#    'id': '920075927987482627',
#    'description': 'Established by Pro Football Hall of Fame NFL great to help inner city youth reach their full potential. Read with Reed83 is the focal literacy program.',
#    'name': 'AndreReedFoundation',
#    'location': 'United States',
#    'verified': False,
#    'username': 'AR83Foundation'},
#   {'public_metrics': {'followers_count': 73633,
#     'following_count': 1907,
#     'tweet_count': 8562,
#     'listed_count': 593},
#    'id': '221383880',
#    'description': 'Former Buffalo #Bills WR #NFL Hall of Fame ‘14 - @BGCA_Club Alum/supporter - Read with Reed83 Literacy Program @ar83foundation philanthropist @profootballhof',
#    'name': 'Andre Reed',
#    'location': 'San Diego',
#    'verified': True,
#    'username': 'Andre_Reed83'},
#   {'public_metrics': {'followers_count': 80424,
#     'following_count': 343,
#     'tweet_count': 4504,
#     'listed_count': 381},
#    'id': '382188294',
#    'description': 'Official Twitter of Hall of Famer, Jim Kelly https://t.co/KerUXPWgUr',
#    'name': 'Jim Kelly',
#    'location': 'Buffalo, New York',
#    'verified': True,
#    'username': 'JimKelly1212'},
#   {'public_metrics': {'followers_count': 519607,
#     'following_count': 8,
#     'tweet_count': 96,
#     'listed_count': 917},
#    'id': '759081003168112640',
#    'description': "Academy Award winning actor currently starring as 'Mickey Donovan' on Showtime's Ray Donovan",
#    'name': 'Jon Voight',
#    'verified': True,
#    'username': 'jonvoight'},
#   {'public_metrics': {'followers_count': 23677,
#     'following_count': 17561,
#     'tweet_count': 163443,
#     'listed_count': 6},
#    'id': '1573472503',
#    'description': 'God .Country. Family. 🇺🇸 Pro-life 👣 GAB @VeeBo345',
#    'name': 'VeBee🇺🇸✝️',
#    'verified': False,
#    'username': 'VeBo1991'},
#   {'public_metrics': {'followers_count': 27831,
#     'following_count': 1561,
#     'tweet_count': 18300,
#     'listed_count': 68},
#    'id': '1090287502475317248',
#    'description': 'Retweets are endorsements of everything that person has ever said or done or thought. Pronouns: The Crown/Your Majesty',
#    'name': 'Taylor Day',
#    'location': 'Based Island',
#    'verified': False,
#    'username': 'TABYTCHI'},
#   {'public_metrics': {'followers_count': 43180,
#     'following_count': 997,
#     'tweet_count': 28689,
#     'listed_count': 334},
#    'id': '4808402532',
#    'description': 'Senior Congressional Correspondent. @DailyCaller. Retweets Are Not Endorsements. DM For Signal. Happiest In A Duck Blind 🦆.',
#    'name': 'Henry Rodgers',
#    'location': 'Washington, DC',
#    'verified': True,
#    'username': 'henryrodgersdc'},
#   {'public_metrics': {'followers_count': 401493,
#     'following_count': 1499,
#     'tweet_count': 12000,
#     'listed_count': 2085},
#    'id': '826065164504006657',
#    'description': "Congresswoman for Georgia's 14th CD, Christian, Wife, Mom, Small Business Owner, Proud American, 100% Pro-Life, Pro-Gun, Pro-Trump #MAGA Likes =/= Endorsements",
#    'name': 'Marjorie Taylor Greene 🇺🇸',
#    'location': 'Georgia, USA',
#    'verified': True,
#    'username': 'mtgreenee'},
#   {'public_metrics': {'followers_count': 97309,
#     'following_count': 1892,
#     'tweet_count': 10932,
#     'listed_count': 468},
#    'id': '29658469',
#    'description': 'Objective reporter • Your African—American!“Telegram: https://t.co/5U9eyVCdVp',
#    'name': 'Jon Miller',
#    'location': 'Los Angeles, CA / DC',
#    'verified': True,
#    'username': 'MillerStream'},
#   {'public_metrics': {'followers_count': 332272,
#     'following_count': 3878,
#     'tweet_count': 17818,
#     'listed_count': 1184},
#    'id': '25816369',
#    'description': 'Tweets represent my own views. Follow my Instagram @DrDavidSamadi. #RoboticSurgery. Expert in https://t.co/QK3ifWiRPB @newsmax contributor🇺🇸🇺🇸🇺🇸',
#    'name': 'Dr. David Samadi, MD',
#    'location': 'Manhattan, New York',
#    'verified': True,
#    'username': 'drdavidsamadi'},
#   {'public_metrics': {'followers_count': 81765,
#     'following_count': 83,
#     'tweet_count': 7870,
#     'listed_count': 1085},
#    'id': '18164887',
#    'description': 'Get personalized Aurora Alerts customized for your location: https://t.co/mB1KHxaO4X',
#    'name': 'Aurora_Alerts',
#    'location': 'USA',
#    'verified': False,
#    'username': 'Aurora_Alerts'},
#   {'public_metrics': {'followers_count': 244355,
#     'following_count': 188,
#     'tweet_count': 15575,
#     'listed_count': 1885},
#    'id': '87679233',
#    'description': 'Former NYT reporter and author of Tell Your Children. Revolting. I took a Louisville slugger to both headlights I slashed a hole in all four tires',
#    'name': 'Alex Berenson',
#    'location': 'New York',
#    'verified': True,
#    'username': 'AlexBerenson'},
#   {'public_metrics': {'followers_count': 19007,
#     'following_count': 6023,
#     'tweet_count': 6885,
#     'listed_count': 36},
#    'id': '1177020086697299971',
#    'description': 'Small Business Accountant! Eagle Scout! Stroke Survivor!I Love My Country. Trump2020!!!  Parler - https://t.co/fNWmYPZTBH',
#    'name': 'Robb Hurst, CPA 🐸',
#    'location': 'Douglas, GA',
#    'verified': False,
#    'username': 'robbhurstCPA'},
#   {'public_metrics': {'followers_count': 9004,
#     'following_count': 134,
#     'tweet_count': 1225,
#     'listed_count': 286},
#    'id': '218482588',
#    'description': 'American Meteor Society official account. - #Nonprofit scientific organization supporting #Meteor #Astronomy and #citizenscience',
#    'name': 'AMSMETEORS',
#    'location': 'USA',
#    'verified': False,
#    'username': 'amsmeteors'},
#   {'public_metrics': {'followers_count': 73805,
#     'following_count': 319,
#     'tweet_count': 780,
#     'listed_count': 307},
#    'id': '1330274087218851852',
#    'description': 'Former Attorney General of Kansas / DA / State Rep. \nDirector, Amistad Project. \nProfessor, Liberty University\nPulpit Pastor\n@freedomcenterlu\n@got_freedom51',
#    'name': 'Phillip Kline',
#    'location': 'Amherst, VA',
#    'verified': False,
#    'username': 'PhillDKline'},
#   {'public_metrics': {'followers_count': 360,
#     'following_count': 1338,
#     'tweet_count': 9301,
#     'listed_count': 3},
#    'id': '818576252323958788',
#    'description': 'I lead a an elite crew that paints luxurious cabinetry using Italian Lacquer . liberty, sound money , Austrian economics and family.',
#    'name': 'RedDoorRefinisher',
#    'location': 'Texas, USA',
#    'verified': False,
#    'username': 'RedDoorRefinish'},
#   {'public_metrics': {'followers_count': 626000,
#     'following_count': 1533,
#     'tweet_count': 85459,
#     'listed_count': 5042},
#    'id': '2853461537',
#    'description': 'My video Micro Lessons on being more effective (at everything) and my most dangerous (to me) humor and content are on Locals: https://t.co/OkSfCM9Kq6',
#    'name': 'Scott Adams',
#    'location': 'Pleasanton CA',
#    'verified': True,
#    'username': 'ScottAdamsSays'},
#   {'public_metrics': {'followers_count': 1263,
#     'following_count': 1306,
#     'tweet_count': 3049,
#     'listed_count': 49},
#    'id': '40883051',
#    'description': "We're here to bring the christian communities together through out reach and community participation",
#    'name': 'Christian Community',
#    'verified': False,
#    'username': 'CCNetworking'},
#   {'public_metrics': {'followers_count': 793,
#     'following_count': 1191,
#     'tweet_count': 17780,
#     'listed_count': 1},
#    'id': '1030384870525218816',
#    'description': 'Politicians are gonna keep poking the bear and WE THE PEOPLE are gonna punch back! UNMASK THE COUNTRY!\n#MAGA #2A #FightBack',
#    'name': 'Kevin Wilbanks @LifeIsGood913',
#    'location': 'McCordsville, IN',
#    'verified': False,
#    'username': 'lifeisgood913'},
#   {'public_metrics': {'followers_count': 43,
#     'following_count': 167,
#     'tweet_count': 1827,
#     'listed_count': 0},
#    'id': '1251926148021391360',
#    'description': '#DemocratsHateAmerica #Trump2020Landslide #MAGA #KAG',
#    'name': 'Robert Noel',
#    'verified': False,
#    'username': 'RobertN10475980'},
#   {'public_metrics': {'followers_count': 19553,
#     'following_count': 13090,
#     'tweet_count': 271607,
#     'listed_count': 42},
#    'id': '1947900744',
#    'description': "Same name on Parler, GAB, CloutHub, Hifiven\nLet's eradicate Communism in USA at all costs!\nSee many of my 270+ vids: \nhttps://t.co/TNHKIyQuNU",
#    'name': '🎵SongBird4Trump🎵 #ReleaseTheKRACKEN!',
#    'location': 'MAGANATION',
#    'verified': False,
#    'username': 'SongBird4Trump'},
#   {'public_metrics': {'followers_count': 2816,
#     'following_count': 1292,
#     'tweet_count': 6485,
#     'listed_count': 4},
#    'id': '1259955664740286464',
#    'description': 'Advocating for accountability & reform for our seniors. Our loved ones died due to COVID nursing home policies and isolation mandated by Governors #cuomocoverup',
#    'name': 'VoicesForSeniors',
#    'verified': False,
#    'username': 'Voices4Seniors'},
#   {'public_metrics': {'followers_count': 8694,
#     'following_count': 18,
#     'tweet_count': 0,
#     'listed_count': 85},
#    'id': '1120024086711652352',
#    'description': 'A Grayzone news show hosted by @aaronjmate. \nSupport: https://t.co/76xj133zu5\nPodcast: https://t.co/8aXUbw7mBp\nVideo: https://t.co/MauaeoZisA',
#    'name': 'Pushback w/ Aaron Maté',
#    'verified': False,
#    'username': 'PushbackShow'},
#   {'public_metrics': {'followers_count': 130958,
#     'following_count': 2645,
#     'tweet_count': 31852,
#     'listed_count': 1392},
#    'id': '153517357',
#    'description': 'Host, @PushbackShow @TheGrayzoneNews. Coming soon: https://t.co/E8200HFqqS  aaronmate@protonmail.com',
#    'name': 'Aaron Maté',
#    'location': 'Brooklyn, NY',
#    'verified': True,
#    'username': 'aaronjmate'},
#   {'public_metrics': {'followers_count': 81243,
#     'following_count': 1643,
#     'tweet_count': 9447,
#     'listed_count': 999},
#    'id': '16366471',
#    'description': 'The official Twitter account of the Tea Party Express. Join us as we elect true conservatives and take our country back!',
#    'name': 'Tea Party Express',
#    'location': 'United States of America',
#    'verified': True,
#    'username': 'TeaPartyExpress'},
#   {'public_metrics': {'followers_count': 23129,
#     'following_count': 14074,
#     'tweet_count': 23437,
#     'listed_count': 831},
#    'id': '18000662',
#    'description': 'The top stories by conservatives for conservatives from the Townhall Media family.',
#    'name': 'Townhall Media',
#    'verified': False,
#    'username': 'TownhallMedia'},
#   {'public_metrics': {'followers_count': 28719,
#     'following_count': 511,
#     'tweet_count': 75572,
#     'listed_count': 1106},
#    'id': '15256077',
#    'description': '🎯 Accuracy in Media uses citizen activism and investigative journalism to expose media bias, corruption, and public policy failings.',
#    'name': 'Accuracy In Media',
#    'location': 'Washington, DC',
#    'verified': False,
#    'username': 'AccuracyInMedia'},
#   {'public_metrics': {'followers_count': 135597,
#     'following_count': 54,
#     'tweet_count': 4468,
#     'listed_count': 530},
#    'id': '704943112217608193',
#    'description': "ED of @lookaheadorg. Frm Data/Strat Dir DJT 2016. Gen Consultant (R). matt@braynard.com.\n\n-k, but what're u gonna' DO about it?\n\nAmerica First. America Forever.",
#    'name': 'Matt Braynard',
#    'verified': False,
#    'username': 'MattBraynard'},
#   {'public_metrics': {'followers_count': 11117,
#     'following_count': 7717,
#     'tweet_count': 79932,
#     'listed_count': 63},
#    'id': '921620790',
#    'description': 'Equine Hoof Rehab * Cutting Horses * God * Constitution * Conservative * 1A & 2A * Veterans * Freedom * John Wayne * #MAGA #KAG2020 #ForeverAcquitted',
#    'name': 'I’m Your Huckleberry',
#    'location': 'Texas, USA',
#    'verified': False,
#    'username': 'RossFairchild'},
#   {'public_metrics': {'followers_count': 103112,
#     'following_count': 88271,
#     'tweet_count': 134490,
#     'listed_count': 803},
#    'id': '27789999',
#    'description': '★★Christian Conservative Retired Fighter Pilot & Wing Commander. Defender of FREEDOM, Invented #MAGA,\nAuthor of TOP GUN MANAGEMENT, Combat Veteran.',
#    'name': '✯✯Gene McVay✯✯',
#    'location': 'Arkansas',
#    'verified': False,
#    'username': 'GeneMcVay'},
#   {'public_metrics': {'followers_count': 83851,
#     'following_count': 2785,
#     'tweet_count': 83286,
#     'listed_count': 477},
#    'id': '879548970082721792',
#    'description': "We don't rise to the level of our expectations, we fall to the level of our training.",
#    'name': 'Rising serpent 🇺🇸',
#    'location': 'USA',
#    'verified': False,
#    'username': 'rising_serpent'},
#   {'public_metrics': {'followers_count': 61615,
#     'following_count': 89,
#     'tweet_count': 18986,
#     'listed_count': 810},
#    'id': '212308700',
#    'description': 'The CEO and founder of Answers in Genesis, the popular Creation Museum, and the world-renowned Ark Encounter.',
#    'name': 'Ken Ham',
#    'verified': False,
#    'username': 'aigkenham'},
#   {'public_metrics': {'followers_count': 338,
#     'following_count': 215,
#     'tweet_count': 890,
#     'listed_count': 9},
#    'id': '443615657',
#    'description': 'Cities4Life™ seeks to bring the light of the Gospel to abortion centers - the darkest places in the city of Charlotte.',
#    'name': 'Cities4Life',
#    'location': 'Charlotte, NC',
#    'verified': False,
#    'username': 'cities4life'},
#   {'public_metrics': {'followers_count': 9282,
#     'following_count': 67,
#     'tweet_count': 4084,
#     'listed_count': 96},
#    'id': '515702270',
#    'description': 'Christ follower | Hubby | Dad | Entrepreneur | Author https://t.co/TgsbY1Nu3D',
#    'name': 'David Benham',
#    'location': 'Charlotte, North Carolina',
#    'verified': False,
#    'username': 'DavidDBenham'},
#   {'public_metrics': {'followers_count': 8432,
#     'following_count': 93,
#     'tweet_count': 3702,
#     'listed_count': 83},
#    'id': '1633144345',
#    'description': 'Followers of Jesus | Husbands | Fathers | Authors | Entrepreneurs https://t.co/TgsbY1Nu3D',
#    'name': 'Benham Brothers',
# ...
#    'username': 'ArthurSchwartz'},
#   {'public_metrics': {'followers_count': 2998,
#     'following_count': 2148,
#     'tweet_count': 1389,
#     'listed_count': 29},
#    'id': '3059661741',
#    'description': 'Serial entrepreneur, millennial, tech guru, & radio talk show host who loves exploring the outdoors, fighting for liberty, and supporting the local community.',
#    'name': 'Andrew C Hollister',
#    'location': 'Rochester, NY',
#    'verified': True,
#    'username': 'achollister'},
#   {'public_metrics': {'followers_count': 38,
#     'following_count': 116,
#     'tweet_count': 122,
#     'listed_count': 0},
#    'id': '988492408538193920',
#    'description': '',
#    'name': 'Caroline Cooke',
#    'verified': False,
#    'username': 'Carolin95272727'},
#   {'public_metrics': {'followers_count': 16414,
#     'following_count': 5529,
#     'tweet_count': 27611,
#     'listed_count': 169},
#    'id': '17581393',
#    'description': 'Husband. Father. Son. Dutchess County Executive. 2018 Candidate for Governor, earned 2.2 million votes.',
#    'name': 'Marc Molinaro',
#    'location': 'Red Hook, NY',
#    'verified': True,
#    'username': 'marcmolinaro'},
#   {'public_metrics': {'followers_count': 25335,
#     'following_count': 1012,
#     'tweet_count': 73173,
#     'listed_count': 197},
#    'id': '23620357',
#    'description': 'AM Drive 6-10a @NJ1015 & Former TV Host/Anchor @foxtv\nFor Bookings: DM or email billspadea@gmail.com\n#SuperSpreaderOfTruth',
#    'name': 'Bill Spadea',
#    'location': 'Princeton NJ',
#    'verified': True,
#    'username': 'BillSpadea'},
#   {'public_metrics': {'followers_count': 72440,
#     'following_count': 1287,
#     'tweet_count': 65257,
#     'listed_count': 1766},
#    'id': '12011422',
#    'description': 'Brian Lehrer leads the conversation about what matters most in local and national politics weekdays at 10am on @WNYC. Subscribe to our Daily Politics Podcast.',
#    'name': 'The Brian Lehrer Show and A Daily Politics Podcast',
#    'location': 'New York, NY',
#    'verified': True,
#    'username': 'BrianLehrer'},
#   {'public_metrics': {'followers_count': 194247,
#     'following_count': 2107,
#     'tweet_count': 102343,
#     'listed_count': 4551},
#    'id': '6576492',
#    'description': 'Independent news, culture and courageous conversation. \n📻 93.9 FM | AM 820 | https://t.co/CSGinZNmkE\n@BrianLehrer, @AllOfItWNYC, @TheTakeaway, @Radiolab, @OnTheMedia & more',
#    'name': 'WNYC 🎙',
#    'location': 'New York City',
#    'verified': True,
#    'username': 'WNYC'},
#   {'public_metrics': {'followers_count': 899515,
#     'following_count': 153,
#     'tweet_count': 352787,
#     'listed_count': 7562},
#    'id': '14216661',
#    'description': 'News, analysis and commentary by the National Post.',
#    'name': 'National Post',
#    'location': 'Canada',
#    'verified': True,
#    'username': 'nationalpost'},
#   {'public_metrics': {'followers_count': 167292,
#     'following_count': 3221,
#     'tweet_count': 24194,
#     'listed_count': 5172},
#    'id': '22737278',
#    'description': 'I run a newsletter called Volts, about clean energy & politics. Subscribe & join the community at https://t.co/EWUU3NwgWl!',
#    'name': 'David Roberts',
#    'location': 'Seattle, WA',
#    'verified': False,
#    'username': 'drvolts'},
#   {'public_metrics': {'followers_count': 142,
#     'following_count': 42,
#     'tweet_count': 32,
#     'listed_count': 5},
#    'id': '211982304',
#    'description': 'BS Physics: Boston College; BS Mathematics: BC; MS Physics: Syracuse University; Employed @ GE Aerospace Electronics, Mohawk Data Sciences, Monolithic Memories',
#    'name': 'John Droz, jr',
#    'location': 'North Carolina',
#    'verified': False,
#    'username': 'JohnDrozjr'},
#   {'public_metrics': {'followers_count': 140,
#     'following_count': 274,
#     'tweet_count': 3293,
#     'listed_count': 3},
#    'id': '637295673',
#    'description': "Former Reactor Operator on US nuclear subs (USS Tunny, SSN682 & USS Robert E Lee, SSBN 601G). Retired Computer Engineer (RPI class of '85)",
#    'name': 'Steve Bunten',
#    'location': 'Aurora, CO',
#    'verified': False,
#    'username': 'smbunten'},
#   {'public_metrics': {'followers_count': 535,
#     'following_count': 1038,
#     'tweet_count': 16059,
#     'listed_count': 10},
#    'id': '955962335696433156',
#    'description': '“It all makes sense if you don’t think about it.” Nuclear Power operations and training for 45 years. Resistentialist.',
#    'name': 'ELI the ICE man, Ugly Chump',
#    'location': 'Old sailor, far from the sea. ',
#    'verified': False,
#    'username': 'EMCMSSRET'},
#   {'public_metrics': {'followers_count': 1228,
#     'following_count': 661,
#     'tweet_count': 4936,
#     'listed_count': 25},
#    'id': '968519274275966978',
#    'description': 'Short informational videos on energy issues and the vital role energy plays in sustaining life, liberty and a vibrant economy. Power On.',
#    'name': 'Clear Energy Alliance',
#    'verified': False,
#    'username': 'clearenergy'},
#   {'public_metrics': {'followers_count': 486,
#     'following_count': 592,
#     'tweet_count': 1650,
#     'listed_count': 8},
#    'id': '302225370',
#    'description': 'Clear Energy Alliance video producer, speaker, documentary filmmaker, author, husband, father, patriot, contrarian.',
#    'name': 'Mark Mathis',
#    'location': 'Dallas, TX',
#    'verified': False,
#    'username': 'TheMarkMathis'},
#   {'public_metrics': {'followers_count': 3836,
#     'following_count': 3555,
#     'tweet_count': 23797,
#     'listed_count': 33},
#    'id': '769531819582627840',
#    'description': 'Our only Special Interest is #FREEDOM\nDefenders of rural America & locally-sourced government 🇺🇸🇺🇸🇺🇸\n#Ranching #Agriculture #Industry #Liberty',
#    'name': 'FreeRangeReport',
#    'location': 'Utah, USA',
#    'verified': False,
#    'username': 'RangeReporter'},
#   {'public_metrics': {'followers_count': 1040,
#     'following_count': 471,
#     'tweet_count': 2156,
#     'listed_count': 45},
#    'id': '39376383',
#    'description': 'Fight privilege. Defend markets. On Parler at DavidKreutzer',
#    'name': 'David Kreutzer',
#    'location': 'Washington, DC area',
#    'verified': False,
#    'username': 'dwkreutzer'},
#   {'public_metrics': {'followers_count': 1338,
#     'following_count': 1742,
#     'tweet_count': 12791,
#     'listed_count': 5},
#    'id': '1100901746',
#    'description': 'ALL people have the same basic rights to succeed or fail on their own efforts .\n\nCome to Parler and follow me https://t.co/GE1D88LJ3d',
#    'name': '🇺🇲Say No to Cuomo🇺🇲',
#    'location': 'The Empire State, New York.',
#    'verified': False,
#    'username': 'SayNoToCuomo'},
#   {'public_metrics': {'followers_count': 387,
#     'following_count': 949,
#     'tweet_count': 3994,
#     'listed_count': 16},
#    'id': '1601913667',
#    'description': "@part_n_parcel | Co-EP - Emmy Winning 'Disgraced' | Producer - 'Juice', 'Don't Ever Change' | Post-Prod - 'High Profits'(CNN), 'Small Business Revolution'",
#    'name': 'Wallis',
#    'location': 'Austin,  TX',
#    'verified': False,
#    'username': 'MatthewLWallis'},
#   {'public_metrics': {'followers_count': 7940,
#     'following_count': 7854,
#     'tweet_count': 223129,
#     'listed_count': 95},
#    'id': '761965519',
#    'description': 'https://t.co/zTJalvzvHX, M.I.Mech.E rtd, commercial diver rtd,  Primitive Methodist, Neo-Chartist not retired and eco-engineer tidal flow power, editor https://t.co/xqCynVAF5E',
#    'name': 'mickoforpington',
#    'location': 'Orpington',
#    'verified': False,
#    'username': 'MickGreenhough'},
#   {'public_metrics': {'followers_count': 1644,
#     'following_count': 2610,
#     'tweet_count': 61804,
#     'listed_count': 48},
#    'id': '1638469639',
#    'description': "Trying to stop climate change is like trying to stop the seasons from changing. We don't control the climate; IT controls US.\n#FixTheFraud #StopCensorship",
#    'name': '4TimesAYear',
#    'verified': False,
#    'username': '4TimesAYear'},
#   {'public_metrics': {'followers_count': 258264,
#     'following_count': 95121,
#     'tweet_count': 307058,
#     'listed_count': 1000},
#    'id': '261749735',
#    'description': 'Official Campaign for Christian Lamar, 2022 Republican candidate for Arizona House of Representatives in Legislative District 20 #AZGOP #LD20 #AZLeg #Arizona',
#    'name': 'Christian For Arizona',
#    'location': 'Phoenix, AZ',
#    'verified': False,
#    'username': 'ChristianForAZ'},
#   {'public_metrics': {'followers_count': 892,
#     'following_count': 1675,
#     'tweet_count': 68584,
#     'listed_count': 20},
#    'id': '3065583047',
#    'description': '',
#    'name': 's.stuart ☃️',
#    'verified': False,
#    'username': 'sstuart57'},
#   {'public_metrics': {'followers_count': 308009,
#     'following_count': 142,
#     'tweet_count': 1840,
#     'listed_count': 1637},
#    'id': '372372537',
#    'description': 'Professor at Harvard Law School for 50 years, now emeritus. Active in litigation, writing, and defense of civil liberties and human rights.',
#    'name': 'Alan Dershowitz',
#    'location': 'Cambridge, MA',
#    'verified': True,
#    'username': 'AlanDersh'},
#   {'public_metrics': {'followers_count': 730,
#     'following_count': 1867,
#     'tweet_count': 824,
#     'listed_count': 8},
#    'id': '2750593189',
#    'description': 'Concerned residents around the Comeragh Mountains regarding industrial wind turbines.   Email:comeraghsagainstturbines@hotmail.com, volunteers welcomed.',
#    'name': 'ComeraghsTurbines',
#    'location': 'Co.Waterford',
#    'verified': False,
#    'username': 'comeraghsAT'},
#   {'public_metrics': {'followers_count': 964,
#     'following_count': 2034,
#     'tweet_count': 44782,
#     'listed_count': 49},
#    'id': '1242448184',
#    'description': 'Started out trying to be apolitical, but the Left has pushed me to the Right.',
#    'name': '🐸AllWeAreSayingIsGiveTrumpAChance🐸',
#    'location': 'Somewhere nearby',
#    'verified': False,
#    'username': 'IdontbelieveinC'},
#   {'public_metrics': {'followers_count': 5046,
#     'following_count': 1014,
#     'tweet_count': 16920,
#     'listed_count': 63},
#    'id': '969860836163547136',
#    'description': 'Belief in science is belief not science.',
#    'name': 'Yota111',
#    'verified': False,
#    'username': 'yota_berlin'},
#   {'public_metrics': {'followers_count': 1144,
#     'following_count': 4143,
#     'tweet_count': 40722,
#     'listed_count': 9},
#    'id': '824735270364930050',
#    'description': 'Land use planner, NOT a social engineer. Sustainability is an evil, authoritarian, collectivist ideology. Don’t @ me with stupid utopia Agenda2030 bullshit.',
#    'name': 'EndLockdownsNow',
#    'location': 'Toronto, Ontario',
#    'verified': False,
#    'username': 'TorontoPushback'},
#   {'public_metrics': {'followers_count': 18533,
#     'following_count': 19074,
#     'tweet_count': 114208,
#     'listed_count': 80},
#    'id': '2289423523',
#    'description': 'Managing Director, Family, Conservative, Freedom of Speech, Chemistry, Climate Changes Always, Trumpeter, Guitarist, Aussie ❌ 😊',
#    'name': 'Mike Jagger',
#    'verified': False,
#    'username': 'JaggerMickOZ'},
#   {'public_metrics': {'followers_count': 13872,
#     'following_count': 4534,
#     'tweet_count': 31307,
#     'listed_count': 173},
#    'id': '48518416',
#    'description': 'Online Opinion Editor  @WashTimes @WashtimesOpEd Author, writer, speaker, https://t.co/28YhOKKtJ5. Licensed Private Investigator (VA DCJS 99-645573). I Block Stupid.',
#    'name': 'cheryl chumley',
#    'location': 'NVA-DC Metro Area',
#    'verified': False,
#    'username': 'ckchumley'},
#   {'public_metrics': {'followers_count': 11456,
#     'following_count': 2742,
#     'tweet_count': 42889,
#     'listed_count': 202},
#    'id': '80741093',
#    'description': 'The voice of health freedom and healing liberty. 3-5 ET M-F, 1-3p ET Sundays',
#    'name': 'Robert Scott Bell',
#    'location': 'The US & world of Health Talk Radio',
#    'verified': False,
#    'username': 'rsbellmedia'},
#   {'public_metrics': {'followers_count': 532,
#     'following_count': 1315,
#     'tweet_count': 1125,
#     'listed_count': 7},
#    'id': '14012622',
#    'description': 'Director of Juice: How Electricity Explains The World. Co-founder of C2C Media. Co-Creator & Producer of The Power Hungry Podcast.',
#    'name': 'Tyson Culver',
#    'location': 'Austin, Texas',
#    'verified': False,
#    'username': 'TysonCulver'},
#   {'public_metrics': {'followers_count': 15409,
#     'following_count': 2848,
#     'tweet_count': 51184,
#     'listed_count': 381},
#    'id': '337778202',
#    'description': "A non-profit education news service chronicling what's happening every day in our nation's schools.",
#    'name': 'Choice Media',
#    'location': 'Hoboken, NJ',
#    'verified': False,
#    'username': 'ChoiceMediatv'},
#   {'public_metrics': {'followers_count': 4035,
#     'following_count': 2211,
#     'tweet_count': 60931,
#     'listed_count': 1},
#    'id': '3103892153',
#    'description': 'Wife to @Seppo_Lipasti | Mother | Health & education professional & researcher (midlife health in women, health promotion) | Finn🇫🇮 relocated to Portugal🇵🇹',
#    'name': 'Maija Lipasti',
#    'location': '☀️Algarve, PT (since 2020)',
#    'verified': False,
#    'username': 'MaijaLipasti'},
#   {'public_metrics': {'followers_count': 175,
#     'following_count': 259,
#     'tweet_count': 19,
#     'listed_count': 0},
#    'id': '836390414181621760',
#    'description': '',
#    'name': 'rwr',
#    'location': 'Tx',
#    'verified': False,
#    'username': 'abcdefghi97'},
#   {'public_metrics': {'followers_count': 782,
#     'following_count': 712,
#     'tweet_count': 101404,
#     'listed_count': 81},
#    'id': '798939415',
#    'description': '',
#    'name': 'Pokkiehat',
#    'verified': False,
#    'username': 'Pokkiehat'},
#   {'public_metrics': {'followers_count': 1021,
#     'following_count': 253,
#     'tweet_count': 51948,
#     'listed_count': 17},
#    'id': '296915285',
#    'description': "Conservative evangelical Christian. Engineer for 35+yrs. As naturally inquisitive, I ask questions, sometimes provocative, but don't be offended.",
#    'name': 'Simon Conway-Smith',
#    'location': 'Cambridgeshire, UK',
#    'verified': False,
#    'username': 'SConwaySmith'},
#   {'public_metrics': {'followers_count': 307,
#     'following_count': 518,
#     'tweet_count': 15461,
#     'listed_count': 6},
#    'id': '755114148',
#    'description': 'Proud to be English. Despise cruelty in any form. Hate the EU.  Believe the majority of politicians are lying, self seeking egomaniacs, want our lives back.',
#    'name': 'Totally random....',
#    'location': 'Earth',
#    'verified': False,
#    'username': '2b_freeforever'},
#   {'public_metrics': {'followers_count': 212,
#     'following_count': 406,
#     'tweet_count': 4692,
#     'listed_count': 1},
#    'id': '247999898',
#    'description': 'Retired journalist. Practicing skeptic. Writer. Traveller. Old enough to say what I think.',
#    'name': 'Michael Hornbrook',
#    'location': 'Mostly Canada',
#    'verified': False,
#    'username': 'mikehornbrook'},
#   {'public_metrics': {'followers_count': 744,
#     'following_count': 990,
#     'tweet_count': 22073,
#     'listed_count': 8},
#    'id': '2667051031',
#    'description': 'The truth will set us free.',
#    'name': 'Daniel McCaffrey',
#    'location': 'Hamilton New Zealand',
#    'verified': False,
#    'username': 'mccaffreydanie1'},
#   {'public_metrics': {'followers_count': 10188,
#     'following_count': 8918,
#     'tweet_count': 90116,
#     'listed_count': 3},
#    'id': '11782232',
#    'description': 'I believe Trump won by a landslide on November 3 and exercised my First Amendment rights in DC on January 6 by peacefully petitioning for an audit.',
#    'name': 'NO MORE MASKS',
#    'location': 'New Hampshire',
#    'verified': False,
#    'username': 'NewHampshireBen'},
#   {'public_metrics': {'followers_count': 1496,
#     'following_count': 3561,
#     'tweet_count': 108370,
#     'listed_count': 25},
#    'id': '136284056',
#    'description': 'From Pharma to the Farm: Ph.D. Pharmacologist/Immunologist, Beekeeper, Wife, Proud Mother of 2 Eagle Scouts, 2 Geologists, 1 Finance Guy. The Honey is Sweet🐝',
#    'name': 'Bonny Wright🐝',
#    'location': 'Out at the Hives',
#    'verified': False,
#    'username': 'miamivandynyu'}],
#  'meta': {'result_count': 998, 'next_token': '7JVQ0P32ESL1CZZZ'}}

# %%
extensionsToCheck = ['a', 'b']
url_string = ['klask']
if any(ext in url_string for ext in extensionsToCheck):
    print(url_string)

# %%
a = connect_to_endpoint('https://api.twitter.com/2/users/485717967/following?max_results=1000&user.fields=public_metrics,location,description,verified&pagination_token=MJ2VSAUJAUT16ZZZ',create_headers(BEARER_TOKEN))

# %%
    print('nice')
# Out:
# nice

# %%
a
# Out:
# {'data': [{'public_metrics': {'followers_count': 61816,
#     'following_count': 46324,
#     'tweet_count': 13720,
#     'listed_count': 875},
#    'username': 'FreeStateNH',
#    'id': '21779975',
#    'name': 'The Free State 🦔',
#    'verified': False,
#    'description': 'There are two types of libertarians:\n\n1. Those okay with losing\n2. Those that live in New Hampshire\n\nhttps://t.co/sT5rDCS2bo',
#    'location': 'New Hampshire'},
#   {'public_metrics': {'followers_count': 5482,
#     'following_count': 3331,
#     'tweet_count': 4799,
#     'listed_count': 109},
#    'username': 'AmerComm',
#    'id': '552744336',
#    'name': 'American Commitment',
#    'verified': False,
#    'description': 'We restore and protect the American Commitment to free markets, economic growth, Constitutionally-limited government, property rights, and individual freedom.'},
#   {'public_metrics': {'followers_count': 16120,
#     'following_count': 15502,
#     'tweet_count': 7370,
#     'listed_count': 108},
#    'username': 'ShelbyCountyGOP',
#    'id': '515573992',
#    'name': 'Shelby County AL GOP 🇺🇸',
#    'verified': False,
#    'description': 'Shelby County is widely recognized as the “most Republican” county in Alabama and ranks as one of the top conservative-friendly counties in America.',
#    'location': 'Shelby County, Alabama'},
#   {'public_metrics': {'followers_count': 427,
#     'following_count': 1807,
#     'tweet_count': 75550,
#     'listed_count': 57},
#    'username': 'KovacsNick',
#    'id': '429183327',
#    'name': '#MAGA Info 🇺🇸✝️',
#    'verified': False,
#    'description': 'Jesus is my Savior & Trump is my president! Info to #MAGA in all aspects of life, with tweets to educate & entertain. God bless America 🖖 #TrumpIsTheBestPOTUS',
#    'location': 'The World Wide Web'},
#   {'public_metrics': {'followers_count': 5855,
#     'following_count': 3411,
#     'tweet_count': 3670,
#     'listed_count': 84},
#    'username': 'PoliticsNY',
#    'id': '966930084',
#    'name': 'PoliticsNY.net',
#    'verified': False,
#    'description': 'A premier web site for Empire State political news. @MichaelRCaputo @ShannonMaura @N_Baldassarre Subscribe: https://t.co/agGjlYFeAk',
#    'location': 'Buffalo, NY'},
#   {'public_metrics': {'followers_count': 24177,
#     'following_count': 19865,
#     'tweet_count': 65333,
#     'listed_count': 316},
#    'username': 'liamkfisher',
#    'id': '562323802',
#    'name': 'Liam Fisher',
#    'verified': False,
#    'description': 'Christian | prepper | veteran'},
#   {'public_metrics': {'followers_count': 23446609,
#     'following_count': 1157,
#     'tweet_count': 688773,
#     'listed_count': 127180},
#    'username': 'Reuters',
#    'id': '1652541',
#    'name': 'Reuters',
#    'verified': True,
#    'description': 'Top and breaking news, pictures and videos from Reuters. For more breaking business news, follow @ReutersBiz.',
#    'location': 'Around the world'},
#   {'public_metrics': {'followers_count': 110936,
#     'following_count': 344,
#     'tweet_count': 6715,
#     'listed_count': 2497},
#    'username': 'SenJohnThune',
#    'id': '296361085',
#    'name': 'Senator John Thune',
#    'verified': True,
#    'description': 'Senate Republican Whip. Representing South Dakota. Father. Grandfather. Husband. Sports Fan. Avid Outdoorsman. Hates Shoveling Snow.\nhttps://t.co/CAJybse6Mc'},
#   {'public_metrics': {'followers_count': 1249859,
#     'following_count': 23860,
#     'tweet_count': 30194,
#     'listed_count': 9025},
#    'username': 'SenateGOP',
#    'id': '14344823',
#    'name': 'Senate Republicans',
#    'verified': True,
#    'description': 'News and updates from Senate Republicans and their staff. Chairman @SenJohnBarrasso.',
#    'location': 'Washington, D.C.'},
#   {'public_metrics': {'followers_count': 527823,
#     'following_count': 1532,
#     'tweet_count': 13978,
#     'listed_count': 3453},
#    'username': 'jasoninthehouse',
#    'id': '17800215',
#    'name': 'Jason Chaffetz',
#    'verified': True,
#    'description': "Fox News Contributor. Author of They Never Let A Crisis Go To Waste, Power Grab & The Deep State. Fmr. Chairman, Oversight & Gov't Reform U.S. House of Reps",
#    'location': 'Utah, USA'},
#   {'public_metrics': {'followers_count': 32855,
#     'following_count': 1093,
#     'tweet_count': 7940,
#     'listed_count': 899},
#    'username': 'RepMcKinley',
#    'id': '240427862',
#    'name': 'David B. McKinley',
#    'verified': True,
#    'description': 'Proud to serve the First District of West Virginia in the U.S. House of Representatives. Member of the Energy and Commerce Committee. Staff-run account'},
#   {'public_metrics': {'followers_count': 15024,
#     'following_count': 387,
#     'tweet_count': 4228,
#     'listed_count': 746},
#    'username': 'RepAdrianSmith',
#    'id': '296245061',
#    'name': 'Rep. Adrian Smith',
#    'verified': True,
#    'description': 'Proudly serving the 3rd District of Nebraska in the U.S. House of Representatives',
#    'location': 'Gering, NE / Washington, DC'},
#   {'public_metrics': {'followers_count': 56745,
#     'following_count': 812,
#     'tweet_count': 15049,
#     'listed_count': 1645},
#    'username': 'RepKevinBrady',
#    'id': '19926675',
#    'name': 'Rep. Kevin Brady',
#    'verified': True,
#    'description': 'Dad. Husband. Top Republican @WaysandMeansGOP. Loves: Baseball, Texas, tax reform.',
#    'location': 'The Woodlands, Texas'},
#   {'public_metrics': {'followers_count': 11088,
#     'following_count': 134,
#     'tweet_count': 1232,
#     'listed_count': 498},
#    'username': 'SamsPressShop',
#    'id': '249288197',
#    'name': 'Sam Johnson',
#    'verified': False,
#    'description': 'Faithfully serving the Third Congressional District of Texas.',
#    'location': 'Third District of Texas'},
#   {'public_metrics': {'followers_count': 26726,
#     'following_count': 4217,
#     'tweet_count': 7052,
#     'listed_count': 1263},
#    'username': 'PeterRoskam',
#    'id': '20015903',
#    'name': 'Peter Roskam',
#    'verified': False,
#    'description': 'Husband, father, and former U.S. Representative for the 6th District of Illinois.',
#    'location': 'Wheaton, IL'},
#   {'public_metrics': {'followers_count': 18229,
#     'following_count': 3013,
#     'tweet_count': 5608,
#     'listed_count': 1014},
#    'username': 'ErikPaulsen',
#    'id': '17513304',
#    'name': 'Erik Paulsen',
#    'verified': True,
#    'description': '',
#    'location': 'Minnesota'},
#   {'public_metrics': {'followers_count': 52,
#     'following_count': 139,
#     'tweet_count': 1232,
#     'listed_count': 0},
#    'username': 'JLJames001',
#    'id': '752356501',
#    'name': 'J.L.James',
#    'verified': False,
#    'description': 'American by birth, Texan by the grace of GOD!!! Love my wife, family and life...hard working and pay my own way, believe if you are able, you should too!!!',
#    'location': 'East Texas'},
#   {'public_metrics': {'followers_count': 28162,
#     'following_count': 1644,
#     'tweet_count': 17,
#     'listed_count': 669},
#    'username': 'kevinyoder',
#    'id': '252819642',
#    'name': 'Kevin Yoder',
#    'verified': True,
#    'description': 'Former Member of Congress from Kansas who served on @HouseAppropsGOP as Chairman of Homeland Security & Legislative Branch.',
#    'location': 'Overland Park, KS'},
#   {'public_metrics': {'followers_count': 23382,
#     'following_count': 2034,
#     'tweet_count': 6225,
#     'listed_count': 1032},
#    'username': 'RepLarryBucshon',
#    'id': '234812598',
#    'name': 'Larry Bucshon, MD',
#    'verified': True,
#    'description': 'Congressman representing Hoosiers from #IN08. Doctor. Member of @HouseCommerce. https://t.co/4eq38gWLlg',
#    'location': "Indiana's 8th District"},
#   {'public_metrics': {'followers_count': 29820,
#     'following_count': 120,
#     'tweet_count': 745,
#     'listed_count': 1497},
#    'username': 'JoeLieberman',
#    'id': '84129740',
#    'name': 'Joe Lieberman',
#    'verified': False,
#    'description': 'Former United States Senator (I-CT)'},
#   {'public_metrics': {'followers_count': 110439,
#     'following_count': 1954,
#     'tweet_count': 4228,
#     'listed_count': 2952},
#    'username': 'GrahamBlog',
#    'id': '14845376',
#    'name': 'Lindsey Graham',
#    'verified': True,
#    'description': 'Twitter feed for U.S. Senator Lindsey Graham of South Carolina.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 243927,
#     'following_count': 919,
#     'tweet_count': 6399,
#     'listed_count': 3241},
#    'username': 'SenRonJohnson',
#    'id': '233737858',
#    'name': 'Senator Ron Johnson',
#    'verified': True,
#    'description': 'Proud to serve Wisconsin in the U.S. Senate.',
#    'location': 'Oshkosh, WI'},
#   {'public_metrics': {'followers_count': 21055,
#     'following_count': 26,
#     'tweet_count': 58812,
#     'listed_count': 575},
#    'username': 'RonPaulNews',
#    'id': '24736981',
#    'name': 'Ron Paul News',
#    'verified': False,
#    'description': 'Revolution, Liberty, Peace, Freedom, Libertarian, Classical Liberal, Austrian Economics, Free Market, Anarcho-Capitalism'},
#   {'public_metrics': {'followers_count': 34816,
#     'following_count': 535,
#     'tweet_count': 7754,
#     'listed_count': 1220},
#    'username': 'C4Liberty',
#    'id': '18122925',
#    'name': 'Campaign for Liberty',
#    'verified': False,
#    'description': 'Reclaim the Republic || Restore the Constitution',
#    'location': 'Springfield, VA'},
#   {'public_metrics': {'followers_count': 3433,
#     'following_count': 112,
#     'tweet_count': 217583,
#     'listed_count': 148},
#    'username': 'BWSchank',
#    'id': '526555848',
#    'name': 'But_Now_Salt',
#    'verified': False,
#    'description': 'New Creation 2Cor5:17\nSaved by Grace 1Cor15:1-4\nAmbassador for Christ 2Cor5:20\n\nAnointed Not Appointed!\n\nDispensational Truth!\n\nTwitta is a Soap Box! Titus 2:1',
#    'location': 'Doctrine Alone is Preeminent.'},
#   {'public_metrics': {'followers_count': 6398,
#     'following_count': 5732,
#     'tweet_count': 20858,
#     'listed_count': 65},
#    'username': 'JimmyEarlWard',
#    'id': '298358188',
#    'name': 'SirJamesJr',
#    'verified': False,
#    'description': '#Trump45 #MAGA #NoCullusion #Trump2020 #2A #ProLife #BuildTheDamnWall #AmericaFirst #LiberalsAreIdiots #CnnSucks #RollTide',
#    'location': 'Alabama, USA '},
#   {'public_metrics': {'followers_count': 94,
#     'following_count': 5,
#     'tweet_count': 1,
#     'listed_count': 0},
#    'username': 'CWMonckton',
#    'id': '101142912',
#    'name': 'About Lord Monckton',
#    'verified': False,
#    'description': 'This feed shares information about Lord Christopher Monckton, but is not administered by him or the office of the Viscount in any way.'},
#   {'public_metrics': {'followers_count': 46626,
#     'following_count': 47678,
#     'tweet_count': 42789,
#     'listed_count': 1302},
#    'username': 'KirkusMacGowan',
#    'id': '258174099',
#    'name': 'Kirkus MacGowan',
#    'verified': False,
#    'description': 'Stay-at-home dad & Amazon bestselling author on (hopefully) temporary hiatus. #mystery, #suspense & #fantasy (WIP) Amazon Author Page - https://t.co/D01zi2WOGa',
#    'location': 'Michigan'},
#   {'public_metrics': {'followers_count': 166,
#     'following_count': 62,
#     'tweet_count': 115,
#     'listed_count': 2},
#    'username': 'SwindleOz',
#    'id': '807911149',
#    'name': 'sWINDle Australia',
#    'verified': False,
#    'description': 'sWINDle Australia aims to raise awareness about the threats which industrial wind turbine developments pose and to inform Australians of the FACTS!!!'},
#   {'public_metrics': {'followers_count': 249798,
#     'following_count': 7528,
#     'tweet_count': 7716,
#     'listed_count': 4303},
#    'username': 'EricCantor',
#    'id': '18891923',
#    'name': 'Eric Cantor',
#    'verified': True,
#    'description': 'Vice Chair and Managing Director, @Moelis; former House Majority Leader. Working to build #AnAmericaThatWorks, #AnAmericaThatLeads. Tweets are my own.',
#    'location': 'Richmond, VA'},
#   {'public_metrics': {'followers_count': 31507,
#     'following_count': 2867,
#     'tweet_count': 5314,
#     'listed_count': 1620},
#    'username': 'RepTomPrice',
#    'id': '6577802',
#    'name': 'Tom Price',
#    'verified': False,
#    'description': "Former U.S. Representative for Georgia's 6th Congressional District & served as the 23rd U.S. Secretary of @HHSGov. This and @SecPriceMD are archived accounts.",
#    'location': 'Washington, D.C.'},
#   {'public_metrics': {'followers_count': 30305,
#     'following_count': 7399,
#     'tweet_count': 3527,
#     'listed_count': 1400},
#    'username': 'VernBuchanan',
#    'id': '20467163',
#    'name': 'Rep. Vern Buchanan',
#    'verified': False,
#    'description': 'U.S. Congressman',
#    'location': "Florida's 16th District"},
#   {'public_metrics': {'followers_count': 39639,
#     'following_count': 1010,
#     'tweet_count': 13361,
#     'listed_count': 1406},
#    'username': 'RepLloydDoggett',
#    'id': '153944899',
#    'name': 'Lloyd Doggett',
#    'verified': True,
#    'description': 'Representing communities from San Antonio to Austin. Chairman of the Health Subcommittee on the House Ways & Means Committee.',
#    'location': 'Texas'},
#   {'public_metrics': {'followers_count': 113,
#     'following_count': 0,
#     'tweet_count': 0,
#     'listed_count': 10},
#    'username': 'RepWallyHerger',
#    'id': '305697188',
#    'name': 'Rep. Wally Herger',
#    'verified': False,
#    'description': ''},
#   {'public_metrics': {'followers_count': 27754,
#     'following_count': 1950,
#     'tweet_count': 5911,
#     'listed_count': 906},
#    'username': 'RepDianeBlack',
#    'id': '110545675',
#    'name': 'Diane Black',
#    'verified': True,
#    'description': 'Wife to Dave, mom of three, and proud "Mimi" to 6 grandchildren. Registered nurse, former #TN06 Congressman, and @HouseBudgetGOP Chair.',
#    'location': 'Gallatin, TN'},
#   {'public_metrics': {'followers_count': 3304,
#     'following_count': 0,
#     'tweet_count': 311,
#     'listed_count': 264},
#    'username': 'RepSandyAdams',
#    'id': '221447516',
#    'name': 'Rep Sandy Adams',
#    'verified': True,
#    'description': 'Former Member of Congress representing Florida’s 24th Congressional District. We have nothing to lose but our chains.'},
#   {'public_metrics': {'followers_count': 30255,
#     'following_count': 867,
#     'tweet_count': 7921,
#     'listed_count': 1157},
#    'username': 'RepHartzler',
#    'id': '237763317',
#    'name': 'Rep. Vicky Hartzler',
#    'verified': True,
#    'description': 'I serve the hardworking Missourians of #MO4. Working to reduce the burden of big government & unleash the American spirit. On @HASCRepublicans and @HouseAgGOP.',
#    'location': 'Harrisonville, Missouri'},
#   {'public_metrics': {'followers_count': 2618,
#     'following_count': 479,
#     'tweet_count': 1587,
#     'listed_count': 216},
#    'username': 'RepCharlesBass',
#    'id': '235289157',
#    'name': 'Rep. Charles Bass',
#    'verified': True,
#    'description': "Welcome to my official Twitter account! I'm honored to represent New Hampshire's 2nd District in Congress and I hope you'll share your thoughts with me.",
#    'location': '2nd District, New Hampshire'},
#   {'public_metrics': {'followers_count': 64384,
#     'following_count': 502,
#     'tweet_count': 7467,
#     'listed_count': 1849},
#    'username': 'SenToddYoung',
#    'id': '234128524',
#    'name': 'Senator Todd Young',
#    'verified': True,
#    'description': 'I proudly serve Hoosier families in the U.S. Senate. Contact my office at (202) 224-5623 for assistance. You can also visit our website for additional info.',
#    'location': 'Indiana'},
#   {'public_metrics': {'followers_count': 20668,
#     'following_count': 294,
#     'tweet_count': 3751,
#     'listed_count': 947},
#    'username': 'DrPhilRoe',
#    'id': '52503751',
#    'name': 'Dr. Phil Roe',
#    'verified': True,
#    'description': 'Official Account of former Congressman Phil Roe, MD.',
#    'location': 'East Tennessee'},
#   {'public_metrics': {'followers_count': 38280,
#     'following_count': 1657,
#     'tweet_count': 3566,
#     'listed_count': 968},
#    'username': 'RepBobGibbs',
#    'id': '234822928',
#    'name': 'Rep. Bob Gibbs',
#    'verified': True,
#    'description': 'R-OH https://t.co/2BckMkGpZV',
#    'location': 'US Congress'},
#   {'public_metrics': {'followers_count': 3091,
#     'following_count': 398,
#     'tweet_count': 700,
#     'listed_count': 216},
#    'username': 'RepRivera',
#    'id': '235719973',
#    'name': 'David Rivera',
#    'verified': True,
#    'description': 'Republican. True conservative. Former United States Congressman.',
#    'location': 'Miami, FL'},
#   {'public_metrics': {'followers_count': 34413,
#     'following_count': 2900,
#     'tweet_count': 6098,
#     'listed_count': 1338},
#    'username': 'RepMikeRogersAL',
#    'id': '33977070',
#    'name': 'Mike Rogers',
#    'verified': True,
#    'description': "I am proud to represent Alabama's Third Congressional District.",
#    'location': 'Washington, D.C./Anniston, AL'},
#   {'public_metrics': {'followers_count': 28786,
#     'following_count': 743,
#     'tweet_count': 2003,
#     'listed_count': 1096},
#    'username': 'SenLummis',
#    'id': '22831059',
#    'name': 'Senator Cynthia Lummis',
#    'verified': True,
#    'description': 'Proud to represent the people of Wyoming in the United States Senate - Lummis rhymes with Hummus',
#    'location': 'Wyoming and Washington D.C.'},
#   {'public_metrics': {'followers_count': 13280,
#     'following_count': 1309,
#     'tweet_count': 1885,
#     'listed_count': 822},
#    'username': 'DrPhilGingrey',
#    'id': '32506723',
#    'name': 'Phil Gingrey, MD',
#    'verified': True,
#    'description': 'Proudly served #GA11 in Congress from 2003 to 2015. Advisory Board at District Policy Group of FaegreDrinker LLC. OB/GYN. Views are my own.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 36645,
#     'following_count': 98,
#     'tweet_count': 3170,
#     'listed_count': 1558},
#    'username': 'RepPeteKing',
#    'id': '18277655',
#    'name': 'Pete King',
#    'verified': True,
#    'description': 'Former U.S. Congressman, Rosemary’s Husband. Go Irish! Let’s Go Mets!',
#    'location': 'Seaford, New York'},
#   {'public_metrics': {'followers_count': 19524,
#     'following_count': 541,
#     'tweet_count': 2224,
#     'listed_count': 826},
#    'username': 'ConnieMackIV',
#    'id': '23121519',
#    'name': 'Connie Mack',
#    'verified': True,
#    'description': 'Ret. Member of Congress, baseball enthusiast, and proud father. Opinions are strong and my own. #FreedomMatters',
#    'location': 'Fort Myers, Florida'},
#   {'public_metrics': {'followers_count': 65400,
#     'following_count': 11301,
#     'tweet_count': 3529,
#     'listed_count': 2497},
#    'username': 'OrrinHatch',
#    'id': '18170310',
#    'name': 'Orrin G. Hatch Foundation',
#    'verified': True,
#    'description': 'The Hatch Center is a forum for political discourse, a springboard for civic engagement, and a world-class repository of modern American legislative history.',
#    'location': 'Salt Lake City, UT; Washington, DC'},
#   {'public_metrics': {'followers_count': 15242,
#     'following_count': 3336,
#     'tweet_count': 4838,
#     'listed_count': 138},
#    'username': 'agcelotto',
#    'id': '19916238',
#    'name': 'Annie Celotto',
#    'verified': False,
#    'description': 'I think that Jesus is a big deal. That pretty much sums me up. \nOwner of @alicepaulgroup. Tweets are my own.',
#    'location': 'Lancaster, PA'},
#   {'public_metrics': {'followers_count': 10303,
#     'following_count': 3572,
#     'tweet_count': 29121,
#     'listed_count': 106},
#    'username': 'KQK2',
#    'id': '32288130',
#    'name': '4 More Years',
#    'verified': False,
#    'description': "The Lord's Been Good to Me",
#    'location': 'Alaska'},
#   {'public_metrics': {'followers_count': 6638,
#     'following_count': 3846,
#     'tweet_count': 3146,
#     'listed_count': 97},
#    'username': 'barefootpatriot',
#    'id': '62407070',
#    'name': 'Barefoot Patriot',
#    'verified': False,
#    'description': 'Official Twitter! Conservative political comedian / satirist radio host of Barefoot And Sick Of It! Called an Asshat by Roseanne Barr! http://t.co/4aE0tCIc',
#    'location': 'West Virginia'},
#   {'public_metrics': {'followers_count': 110495,
#     'following_count': 88777,
#     'tweet_count': 234476,
#     'listed_count': 658},
#    'username': 'Dbargen',
#    'id': '23195603',
#    'name': 'Dale Now❌ #COVFEFE',
#    'verified': False,
#    'description': 'Click LIKES for Twitter TIPS! #MAGA Parler: https://t.co/clByXVNdXl GAB: https://t.co/3g16rv4SIA Discord: @Dbargen MeWe Clthb Telegram',
#    'location': 'Send ⭐️DM 4 Follow Back!'},
#   {'public_metrics': {'followers_count': 43230,
#     'following_count': 30639,
#     'tweet_count': 6296,
#     'listed_count': 232},
#    'username': 'Thomasjwhitmore',
#    'id': '18653708',
#    'name': 'Tom Whitmore',
#    'verified': False,
#    'description': 'Retired CEO, conservative, USAF Vet. You have a choice, you either stand 4 something, or you stand 4 nothing, which will be your legacy? Semper Libertas! #MAGA',
#    'location': 'Manassas, Va'},
#   {'public_metrics': {'followers_count': 42650,
#     'following_count': 672,
#     'tweet_count': 9333,
#     'listed_count': 1200},
#    'username': 'TaxPolicyCenter',
#    'id': '61083476',
#    'name': 'Tax Policy Center',
#    'verified': True,
#    'description': 'Independent, timely, accessible analyses of current and emerging tax policy issues. (Links/RTs/favorites/follows/etc. are not endorsements.)',
#    'location': 'Washington DC'},
#   {'public_metrics': {'followers_count': 1163,
#     'following_count': 3562,
#     'tweet_count': 6624,
#     'listed_count': 19},
#    'username': 'alertedge',
#    'id': '248430736',
#    'name': 'alertedge',
#    'verified': False,
#    'description': '..values clear thinking, honest logic and sound rationales in matters of politics, environment and ‘big picture’ stuff of life, truth, purpose, faith and right.',
#    'location': 'Ottawa, CANADA'},
#   {'public_metrics': {'followers_count': 506,
#     'following_count': 1411,
#     'tweet_count': 12271,
#     'listed_count': 26},
#    'username': 'DeeVanProject',
#    'id': '429955927',
#    'name': 'DEE',
#    'verified': False,
#    'description': '',
#    'location': 'Amherst Island'},
#   {'public_metrics': {'followers_count': 1129,
#     'following_count': 94,
#     'tweet_count': 166,
#     'listed_count': 20},
#    'username': 'ColonyBayTV',
#    'id': '254222981',
#    'name': 'Colony Bay TV',
#    'verified': False,
#    'description': 'Colony Bay Productions is dedicated to telling the adventurous, heroic and exceptional story of America in a way that both challenges and inspires the audience.',
#    'location': 'Pasadena/Oak Glen, CA'},
#   {'public_metrics': {'followers_count': 5137,
#     'following_count': 5419,
#     'tweet_count': 1324,
#     'listed_count': 51},
#    'username': 'JCJameson',
#    'id': '783362552',
#    'name': 'JC Jameson',
#    'verified': False,
#    'description': "Architect. Conservative. Catholic. Floridian. Friends got me on Twitter to see what it's about and waste my time"},
#   {'public_metrics': {'followers_count': 164,
#     'following_count': 119,
#     'tweet_count': 3121,
#     'listed_count': 7},
#    'username': 'SupportEvag',
#    'id': '578952144',
#    'name': 'EVAGSUPPORT',
#    'verified': False,
#    'description': 'EVAG - acting to prevent blight, by 115m wind turbines, of Loch Lomond and West Stirlingshire',
#    'location': 'West Stirlingshire, Scotland'},
#   {'public_metrics': {'followers_count': 1327,
#     'following_count': 878,
#     'tweet_count': 12698,
#     'listed_count': 18},
#    'username': 'WindConcernsONT',
#    'id': '436206235',
#    'name': 'Wind Concerns',
#    'verified': False,
#    'description': 'Wind Concerns Ontario is opposed to the siting of industrial-scale wind power generators near homes and communities. #noise #environment #WindDoesntWork',
#    'location': 'Ontario'},
#   {'public_metrics': {'followers_count': 2357,
#     'following_count': 1676,
#     'tweet_count': 167388,
#     'listed_count': 149},
#    'username': 'noturbine',
#    'id': '167446775',
#    'name': 'Bill Heller',
#    'verified': False,
#    'description': 'The people of Union Beach fought hard to prevent our sewage plant from building a loud 40-story industrial wind turbine in our Bayshore town.',
#    'location': 'Moved to Broward County, FL'},
#   {'public_metrics': {'followers_count': 2704,
#     'following_count': 1250,
#     'tweet_count': 120970,
#     'listed_count': 68},
#    'username': 'no2wind',
#    'id': '866906880',
#    'name': 'S.W.A.T',
#    'verified': False,
#    'description': 'Scottish Wind Attack Team  🇬🇧 \nAttacking spin & dishonesty around wind industry. Fighting to protect communities, environment & wildlife\nLies not accepted.',
#    'location': 'Scotland, United Kingdom'},
#   {'public_metrics': {'followers_count': 261,
#     'following_count': 305,
#     'tweet_count': 460,
#     'listed_count': 5},
#    'username': 'ManversWind',
#    'id': '919972968',
#    'name': 'ManversWindConcerns',
#    'verified': False,
#    'description': 'Looking after the Health and Safety of Residents and the Environment on the Oak Ridges Moraine.',
#    'location': 'City of Kawartha Lakes, ON'},
#   {'public_metrics': {'followers_count': 67,
#     'following_count': 59,
#     'tweet_count': 592,
#     'listed_count': 1},
#    'username': 'drtEBiz_OntWind',
#    'id': '570420486',
#    'name': 'dirtyBiz Ont-Timeshare',
#    'verified': False,
#    'description': "outta the Wind Turbine racket & into Time-Share Scams. Easier money, impenetrable legals. Rip'em till they die then gouge their kids.  #maintenancefees r Gold!"},
#   {'public_metrics': {'followers_count': 46926,
#     'following_count': 734,
#     'tweet_count': 44664,
#     'listed_count': 1130},
#    'username': 'TaxFoundation',
#    'id': '16686673',
#    'name': 'Tax Foundation',
#    'verified': True,
#    'description': '📚 Principled research\n🔍 Insightful analysis\n🔌 Engaged experts\n\n| Trusted resource for U.S. and international tax news, research, and analysis for 80+ years.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 12321,
#     'following_count': 12215,
#     'tweet_count': 240940,
#     'listed_count': 278},
#    'username': 'shelliecorreia',
#    'id': '369029151',
#    'name': '❌Shadowbanned, R. U.?',
#    'verified': False,
#    'description': 'TRUTH, NOT TURBINES Countless people swallow sugar-coated lies, but refuse to taste the plain truth.   Evil is the imposition of silence, upon others. JPC',
#    'location': 'Niagara Region, Ontario CA'},
#   {'public_metrics': {'followers_count': 142988,
#     'following_count': 134240,
#     'tweet_count': 1933,
#     'listed_count': 522},
#    'username': 'NatShupe',
#    'id': '158060289',
#    'name': 'Nat ™',
#    'verified': False,
#    'description': 'Constitutional Conservative / 2A / UNLV alumni / ΜΟΛΩΝ ΛΑΒΕ / 4th degree Kenpo / Parler @Nat / Gab @natshupe / I block morons',
#    'location': 'Las Vegas, NV'},
#   {'public_metrics': {'followers_count': 36512,
#     'following_count': 32543,
#     'tweet_count': 83897,
#     'listed_count': 438},
#    'username': 'Thomas_More_Law',
#    'id': '258527170',
#    'name': 'Thomas More Law',
#    'verified': False,
#    'description': "We exist to defend the Constitution, our Judeo/Christian heritage, pro-life, a strong Nat'l Defense & fight against radical Islam. Join us: https://t.co/lC0fqUPnOk",
#    'location': 'Ann Arbor, Michigan'},
#   {'public_metrics': {'followers_count': 21944,
#     'following_count': 20104,
#     'tweet_count': 57312,
#     'listed_count': 277},
#    'username': 'Moira1987',
#    'id': '568240602',
#    'name': 'Moira ☘️ ن',
#    'verified': False,
#    'description': 'Catholic, Conservative, looking to disrupt The Narrative as often as possible! Abair leat! #HH #CelticFamily #RubioRepublican #IStandWithBrett #ConfirmKavanaugh',
#    'location': '4,112 miles from Paradise!'},
#   {'public_metrics': {'followers_count': 18826,
#     'following_count': 14168,
#     'tweet_count': 197989,
#     'listed_count': 587},
#    'username': 'southsalem',
#    'id': '31057963',
#    'name': 'BarbaraMcMahon((🐸))',
#    'verified': False,
#    'description': '#MAGA #AmYIsraelChai\n#RollingStones #Photography \nClinging to my Taurus TheJudge & Chanel ;) #NeverHillary \nhttps://t.co/EhnNnLlwzb',
#    'location': 'Drinking TrumpWine at TrumpBar'},
#   {'public_metrics': {'followers_count': 426617,
#     'following_count': 12873,
#     'tweet_count': 262387,
#     'listed_count': 2127},
#    'username': 'WayneDupreeShow',
#    'id': '282695161',
#    'name': 'Wayne Dupree Media, LLC',
#    'verified': True,
#    'description': 'Official Acct for https://t.co/zPDNB3P5bA; Podcast App 👉🏽 https://t.co/P87APUuYbJ #Bitcoin Donations 👉🏽1P99zH4pE5fy4LMPy65r4A3LpcHyS7Vfzn #CRO #BNB',
#    'location': 'USAF Desert Storm/Shield Vet'},
#   {'public_metrics': {'followers_count': 827031,
#     'following_count': 1897,
#     'tweet_count': 51145,
#     'listed_count': 4297},
#    'username': 'KatiePavlich',
#    'id': '48459553',
#    'name': 'Katie Pavlich',
#    'verified': True,
#    'description': 'Born free 🇺🇸 katiepavlich10@protonmail.com',
#    'location': 'On Instagram/Off Twitter wknds'},
#   {'public_metrics': {'followers_count': 277826,
#     'following_count': 28546,
#     'tweet_count': 21920,
#     'listed_count': 4188},
#    'username': 'DarrellIssa',
#    'id': '22509548',
#    'name': 'Darrell Issa',
#    'verified': True,
#    'description': 'Entrepreneur, Former CEO, Congressman from California.\n\nVisit my website: https://t.co/yBNW2oBCYd'},
#   {'public_metrics': {'followers_count': 22309,
#     'following_count': 13182,
#     'tweet_count': 2259,
#     'listed_count': 184},
#    'username': 'TxRightWing',
#    'id': '707305604',
#    'name': 'Texas Conservative',
#    'verified': False,
#    'description': 'I have a pickup truck, guns, a bar-b-que pit & I know how to use all three. Sadly Graduated Limbaugh Institute Adanced Consevative Studies 2-17-21  ΜΟΛΩΝ ΛΑΒΕ',
#    'location': 'Republic of Texas'},
#   {'public_metrics': {'followers_count': 114694,
#     'following_count': 95618,
#     'tweet_count': 59213,
#     'listed_count': 1060},
#    'username': 'AndyWendt',
#    'id': '11102352',
#    'name': 'Andy Wendt',
#    'verified': False,
#    'description': 'Ohio Constitutionalist, Christian, Highly Flawed. #Security #History #Tech #Science #2a #ProLife Second Home Is https://t.co/BnYHHF4ubH - Opinions Are My Own',
#    'location': 'Ohio, USA'},
#   {'public_metrics': {'followers_count': 93529,
#     'following_count': 34756,
#     'tweet_count': 141290,
#     'listed_count': 1604},
#    'username': 'KOSMOSNET',
#    'id': '49224286',
#    'name': 'Night Owl',
#    'verified': False,
#    'description': 'Conservative, Constitutionalist, Concerned Citizen, #TCOT, #TLOT,',
#    'location': 'USA'},
#   {'public_metrics': {'followers_count': 162356,
#     'following_count': 108835,
#     'tweet_count': 168076,
#     'listed_count': 1707},
#    'username': 'tjholthaus',
#    'id': '28162811',
#    'name': 'Tom Holthaus',
#    'verified': False,
#    'description': 'Retired software  exec. Conservative/ Libertarian,. Korean Vet USAF Officer , 2nd Amendment Defender, World Traveler, Fiscal Conservative  #TCOT #TLOT',
#    'location': 'Olympia, WA'},
#   {'public_metrics': {'followers_count': 257,
#     'following_count': 92,
#     'tweet_count': 516,
#     'listed_count': 5},
#    'username': 'Kevin_Struyk',
#    'id': '52401276',
#    'name': 'Kevin Struyk',
#    'verified': False,
#    'description': 'Servant of the Lord.  Husband and father.',
#    'location': 'Orlando, FL'},
#   {'public_metrics': {'followers_count': 1176,
#     'following_count': 491,
#     'tweet_count': 3378,
#     'listed_count': 44},
#    'username': 'CornwallSteward',
#    'id': '34609195',
#    'name': 'Cornwall Alliance',
#    'verified': False,
#    'description': 'A national coalition committed to bringing a balanced, Biblical view of stewardship to the critical issues of environment and development'},
#   {'public_metrics': {'followers_count': 13547,
#     'following_count': 67,
#     'tweet_count': 1283,
#     'listed_count': 151},
#    'username': 'dkguthrie13',
#    'id': '460748307',
#    'name': 'Dustin Guthrie',
#    'verified': False,
#    'description': ''},
#   {'public_metrics': {'followers_count': 1782,
#     'following_count': 618,
#     'tweet_count': 66966,
#     'listed_count': 109},
#    'username': 'soderstrom',
#    'id': '17938955',
#    'name': 'Erik Soderstrom',
#    'verified': False,
#    'description': "Conservative Blogger. Board Member at @ConcealedCampus and @SCCF. @TwitchyTeam & @SBAList's WSO PAC alum.",
#    'location': 'Virginia Beach, VA'},
#   {'public_metrics': {'followers_count': 2882,
#     'following_count': 991,
#     'tweet_count': 70764,
#     'listed_count': 104},
#    'username': 'wyclif',
#    'id': '6463',
#    'name': 'wyclif ⚓',
#    'verified': False,
#    'description': '🇬🇧🇨🇦🇺🇸 Anglican curate. Former land surveyor. Pilgrim to Jerusalem—also Athens, Rome, London, & Philadelphia. Deep Churchman. Notorious as the #WAT OG.',
#    'location': 'City-Upon-a-Hill'},
#   {'public_metrics': {'followers_count': 1484,
#     'following_count': 1634,
#     'tweet_count': 24914,
#     'listed_count': 40},
#    'username': 'DZJumpmaster',
#    'id': '530803101',
#    'name': 'Kenneth Baschke',
#    'verified': False,
#    'description': 'Retired SGM 5th Special Forces Gp.  Ft. Campbell KY. God, Country, Family.  Freedom needs to be protected, or it will be lost.',
#    'location': 'Utah'},
#   {'public_metrics': {'followers_count': 401669,
#     'following_count': 2030,
#     'tweet_count': 129419,
#     'listed_count': 2865},
#    'username': 'HeyTammyBruce',
#    'id': '22956220',
#    'name': 'Tammy Bruce',
#    'verified': True,
#    'description': "@FoxNews Contributor, @FoxNation Host, Italian. Scottish. Bookish. “Life shrinks or expands in proportion to one's courage.” -Anaïs Nin",
#    'location': 'New York/Los Angeles'},
#   {'public_metrics': {'followers_count': 4595367,
#     'following_count': 85,
#     'tweet_count': 2807,
#     'listed_count': 11607},
#    'username': 'TimTebow',
#    'id': '166270127',
#    'name': 'Tim Tebow',
#    'verified': True,
#    'description': 'Text me ➡️ (904) 441-5450'},
#   {'public_metrics': {'followers_count': 6798,
#     'following_count': 2658,
#     'tweet_count': 150242,
#     'listed_count': 247},
#    'username': 'Pqlyur1',
#    'id': '89120565',
#    'name': 'Cisgendered Gen X Male',
#    'verified': False,
#    'description': 'Generalized Anxiety Disorder included!',
#    'location': 'Nunya, Bidness'},
#   {'public_metrics': {'followers_count': 5071,
#     'following_count': 2882,
#     'tweet_count': 81377,
#     'listed_count': 235},
#    'username': 'AltAnalyst',
#    'id': '60429771',
#    'name': 'Kristi Assange. Ω',
#    'verified': False,
#    'description': 'Catholic. CEO @wikileaks. Critic. Family-Loving @JoeBiden Supporter. 💕 CEO @wikileaks J @assange’s SoulMate. 💕 Intel Analyst. #Privacy #Security',
#    'location': 'Ohio, USA'},
#   {'public_metrics': {'followers_count': 1164,
#     'following_count': 1418,
#     'tweet_count': 611,
#     'listed_count': 9},
#    'username': 'JGoreman',
#    'id': '531827608',
#    'name': 'John Goreman',
#    'verified': False,
#    'description': "I'm a former public servant turned whistle blower and I am here to expose tidbits of information the Government does not want you the public to know!",
#    'location': 'Toronto'},
#   {'public_metrics': {'followers_count': 33803,
#     'following_count': 19132,
#     'tweet_count': 6111,
#     'listed_count': 193},
#    'username': 'Cross_Quotes',
#    'id': '374777707',
#    'name': 'Cross Quotes',
#    'verified': False,
#    'description': 'Quotes by great Christians that will help keep you near the cross of Christ.',
#    'location': 'On A Hill Far Away'},
#   {'public_metrics': {'followers_count': 2324,
#     'following_count': 126,
#     'tweet_count': 704,
#     'listed_count': 21},
#    'username': 'AEFeagles',
#    'id': '560686701',
#    'name': 'American Eagle Foundation',
#    'verified': False,
#    'description': 'The American Eagle Foundation is dedicated to preserving the Bald Eagle and other birds of prey through education, repopulation, conservation, & rehabilitation.',
#    'location': 'Pigeon Forge, Tennessee'},
#   {'public_metrics': {'followers_count': 5460,
#     'following_count': 1154,
#     'tweet_count': 1902,
#     'listed_count': 114},
#    'username': 'kbalfe',
#    'id': '16971793',
#    'name': 'Kevin Balfe',
#    'verified': False,
#    'description': 'partner @redseatventures, exec. producer of @crimeconHQ, angel & real estate investor.',
#    'location': 'New York City'},
#   {'public_metrics': {'followers_count': 24942,
#     'following_count': 1967,
#     'tweet_count': 5171,
#     'listed_count': 1234},
#    'username': 'RepKenMarchant',
#    'id': '23976316',
#    'name': 'Former Rep. Kenny Marchant',
#    'verified': True,
#    'description': 'Former Rep. Kenny Marchant proudly represented the 24th Congressional District of Texas from Jan. 2005 - Jan. 2021.',
#    'location': 'Irving and Washington, D.C.'},
#   {'public_metrics': {'followers_count': 82075,
#     'following_count': 906,
#     'tweet_count': 42724,
#     'listed_count': 1246},
#    'username': 'SheilaWalsh',
#    'id': '15179770',
#    'name': 'SheilaWalsh',
#    'verified': False,
#    'description': 'Born in Scotland, now US citizen, wife ❤️, 1 amazing son 💙and 2 pups. Overwhelmed by the fiery love and mercy of God, found it impossible to keep it to myself',
#    'location': 'In an airport somewhere'},
#   {'public_metrics': {'followers_count': 943971,
#     'following_count': 50,
#     'tweet_count': 4701,
#     'listed_count': 6639},
#    'username': 'DaveRamsey',
#    'id': '8559342',
#    'name': 'Dave Ramsey',
#    'verified': True,
#    'description': 'Author of seven national best sellers. Host of @RamseyShow Follow my team @RachelCruze @ChristyBWright @KenColeman @AnthonyOneal @JohnDelony',
#    'location': 'Nashville, TN'},
#   {'public_metrics': {'followers_count': 303,
#     'following_count': 809,
#     'tweet_count': 3619,
#     'listed_count': 9},
#    'username': 'Oostpolder',
#    'id': '571817509',
#    'name': 'Oostpolder',
#    'verified': False,
#    'description': '',
#    'location': 'Oostpolder'},
#   {'public_metrics': {'followers_count': 322,
#     'following_count': 522,
#     'tweet_count': 228,
#     'listed_count': 3},
#    'username': 'NeelyOotR',
#    'id': '935426814',
#    'name': 'Jeremiah OotR',
#    'verified': False,
#    'description': 'Constitutional conservative, Patriot, Devil Dog, amature photographer, Want to bring sanity back to this country, and inform people of the truth.',
#    'location': 'Tea Party, Virginia'},
#   {'public_metrics': {'followers_count': 8725,
#     'following_count': 279,
#     'tweet_count': 12864,
#     'listed_count': 196},
#    'username': 'oneplacecom',
#    'id': '28159675',
#    'name': 'OnePlace.com',
#    'verified': False,
#    'description': 'http://t.co/MToXpVzQ7n is the leading provider of Christian audio content on the Internet. Listen to pastors and ministries as they deliver Bible based sermons.'},
#   {'public_metrics': {'followers_count': 24553,
#     'following_count': 319,
#     'tweet_count': 2080,
#     'listed_count': 1177},
#    'username': 'RepJoeBarton',
#    'id': '19929362',
#    'name': 'Joe Barton',
#    'verified': True,
#    'description': 'I work for the people of the 6th District of Texas and am honored to represent them in Washington.',
#    'location': 'Ennis, TX'},
#   {'public_metrics': {'followers_count': 76575,
#     'following_count': 339,
#     'tweet_count': 4017,
#     'listed_count': 2341},
#    'username': 'JimInhofe',
#    'id': '7270292',
#    'name': 'Sen. Jim Inhofe',
#    'verified': True,
#    'description': 'United States Senator from the great state of Oklahoma.',
#    'location': 'Oklahoma'},
#   {'public_metrics': {'followers_count': 255,
#     'following_count': 90,
#     'tweet_count': 254,
#     'listed_count': 7},
#    'username': 'revoltgroup',
#    'id': '841342682',
#    'name': 'revoltgroup',
#    'verified': False,
#    'description': 'Rural Economies and Voters Oppose Loveden Turbines',
#    'location': 'United Kingdom'},
#   {'public_metrics': {'followers_count': 192751,
#     'following_count': 18831,
#     'tweet_count': 38035,
#     'listed_count': 3672},
#    'username': 'audubonsociety',
#    'id': '19711765',
#    'name': 'Audubon Society',
#    'verified': True,
#    'description': 'The original tweeters. \nAudubon protects birds and the places they need, today and tomorrow.',
#    'location': 'U.S.'},
#   {'public_metrics': {'followers_count': 27236,
#     'following_count': 29344,
#     'tweet_count': 102898,
#     'listed_count': 394},
#    'username': 'FreebyrdWil',
#    'id': '19605809',
#    'name': 'Wil Rivait',
#    'verified': False,
#    'description': "Entrepreneur\\Sotheby's Real Estate Broker\\Marketing Professional\\Connecting Beautiful People To Learn, Share And Grow With World Wide\\Love God\\Family\\USA",
#    'location': 'Southwest Florida'},
#   {'public_metrics': {'followers_count': 86246,
#     'following_count': 98152,
#     'tweet_count': 32066,
#     'listed_count': 994},
#    'username': 'SINOradio',
#    'id': '54229868',
#    'name': 'SINAO',
#    'verified': False,
#    'description': 'Think Like Our Founding Fathers\nFollow Me on Gab! - @SINAO',
#    'location': 'USA - Make America Great Again'},
#   {'public_metrics': {'followers_count': 2318,
#     'following_count': 2136,
#     'tweet_count': 6793,
#     'listed_count': 41},
#    'username': 'RebeccaAnn81',
#    'id': '443448838',
#    'name': 'Rebecca Ann',
#    'verified': False,
#    'description': 'Indy libertarian/minarchist. Recovering perfectionist. Professional creator of awkward moments. #LAKings',
#    'location': 'Phoenix, AZ'},
#   {'public_metrics': {'followers_count': 11680,
#     'following_count': 8441,
#     'tweet_count': 56462,
#     'listed_count': 174},
#    'username': 'khalifallah',
#    'id': '421482987',
#    'name': "You Ain't Black Khalif!!!",
#    'verified': False,
#    'description': 'Just a sinner acknowledging that GOD is the beginning and the end in the name of JESUS!!! #TrumPence2020',
#    'location': 'Brockton, MA '},
#   {'public_metrics': {'followers_count': 29299,
#     'following_count': 22375,
#     'tweet_count': 48922,
#     'listed_count': 279},
#    'username': 'PointlessPol',
#    'id': '805669518',
#    'name': '4th-Party Pol',
#    'verified': False,
#    'description': 'An anti-activist activist. Libertarian #NeverAnyone',
#    'location': 'FL Ocala National Forest'},
#   {'public_metrics': {'followers_count': 12766,
#     'following_count': 12882,
#     'tweet_count': 44289,
#     'listed_count': 306},
#    'username': 'tnlawgirl',
#    'id': '26582786',
#    'name': 'Patriot',
#    'verified': False,
#    'description': 'Conservative trial lawyer. Fighter for truth, justice and the American way! (and scuba diver) #prolife #tcot #RollTide #TeaParty #TGDN',
#    'location': 'Nashville TN'},
#   {'public_metrics': {'followers_count': 2167,
#     'following_count': 2441,
#     'tweet_count': 38653,
#     'listed_count': 35},
#    'username': 'PatriotintheUSA',
#    'id': '388768730',
#    'name': 'Donald🇺🇸',
#    'verified': False,
#    'description': 'Proud American, Pro Israel, Pro Military, Pro Law Enforcement, #ProLife, Pro #TeaParty, Conservative. Libertarian on Some Issues #MAGA #KAG #Trump2020 #tcot #2A',
#    'location': 'Defiance,PA'},
#   {'public_metrics': {'followers_count': 3386,
#     'following_count': 1068,
#     'tweet_count': 21012,
#     'listed_count': 64},
#    'username': 'Cartoonsbyjosh',
#    'id': '380517384',
#    'name': 'Cartoons by Josh',
#    'verified': False,
#    'description': 'Saving the planet, one cartoon at a time.',
#    'location': 'London, UK'},
#   {'public_metrics': {'followers_count': 11997,
#     'following_count': 37,
#     'tweet_count': 8737,
#     'listed_count': 181},
#    'username': 'precept_usa',
#    'id': '22032376',
#    'name': 'Precept',
#    'verified': False,
#    'description': 'Engaging people in relationship with God through Knowing His Word.',
#    'location': 'Chattanooga, TN'},
#   {'public_metrics': {'followers_count': 19716,
#     'following_count': 2987,
#     'tweet_count': 6689,
#     'listed_count': 608},
#    'username': 'rowenamason',
#    'id': '21177481',
#    'name': 'Rowena Mason',
#    'verified': True,
#    'description': 'Deputy political editor at The Guardian, now on maternity leave. Email me at rowena.mason@theguardian.com',
#    'location': 'London'},
#   {'public_metrics': {'followers_count': 3050405,
#     'following_count': 827,
#     'tweet_count': 415771,
#     'listed_count': 19008},
#    'username': 'Telegraph',
#    'id': '16343974',
#    'name': 'The Telegraph',
#    'verified': True,
#    'description': 'Think ahead with the latest news, comment, analysis and video. Subscribe here: https://t.co/5w4N0n9PeZ',
#    'location': 'London, UK'},
#   {'public_metrics': {'followers_count': 108477,
#     'following_count': 342,
#     'tweet_count': 16906,
#     'listed_count': 1180},
#    'username': 'FocusFamily',
#    'id': '111704438',
#    'name': 'Focus on the Family',
#    'verified': True,
#    'description': 'Focus on the Family is a global Christian ministry helping families thrive! We love encouragement and insight on #marriage and #parenting.  #SeeLife2021',
#    'location': 'Colorado Springs, CO'},
#   {'public_metrics': {'followers_count': 2630064,
#     'following_count': 6,
#     'tweet_count': 27897,
#     'listed_count': 10007},
#    'username': 'marklevinshow',
#    'id': '38495835',
#    'name': 'Mark R. Levin',
#    'verified': True,
#    'description': 'THIS IS THE OFFICIAL MARK LEVIN SHOW TWITTER PAGE. \nDOWNLOAD MY PODCAST FOR FREE https://t.co/HUEgXS3l2C',
#    'location': 'Underground Bunker'},
#   {'public_metrics': {'followers_count': 327635,
#     'following_count': 1360,
#     'tweet_count': 123751,
#     'listed_count': 5838},
#    'username': 'NRO',
#    'id': '19417492',
#    'name': 'National Review',
#    'verified': True,
#    'description': 'Standing athwart history, yelling Stop. A magazine founded by the late William F. Buckley Jr. \nTo send tips: https://t.co/wH7mvUJZdI \nInstagram: NationalReview',
#    'location': 'New York'},
#   {'public_metrics': {'followers_count': 94319,
#     'following_count': 1827,
#     'tweet_count': 38262,
#     'listed_count': 796},
#    'username': 'WilkowMajority',
#    'id': '44397959',
#    'name': 'Andrew Wilkow',
#    'verified': True,
#    'description': 'Official acct for Andrew Wilkow. Host of the Wilkow Majority @SiriusXMPatriot channel 125 & WILKOW! @BlazeTV https://t.co/Ehacx6ILNE',
#    'location': 'New Jersey'},
#   {'public_metrics': {'followers_count': 1882352,
#     'following_count': 32,
#     'tweet_count': 8670,
#     'listed_count': 7091},
#    'username': 'netanyahu',
#    'id': '17061263',
#    'name': 'Benjamin Netanyahu',
#    'verified': True,
#    'description': "ראש ממשלת ישראל ויו''ר הליכוד • Prime Minister of Israel, Chairman of the Likud Party https://t.co/jjO4V91WG1",
#    'location': 'Israel'},
#   {'public_metrics': {'followers_count': 7527,
#     'following_count': 7355,
#     'tweet_count': 147279,
#     'listed_count': 177},
#    'username': 'flyoverangel',
#    'id': '212992600',
#    'name': 'Kelly',
#    'verified': False,
#    'description': 'cynical ray of sunshine, optimist fully planning on the worst',
#    'location': 'Wonderland between NY and LA'},
#   {'public_metrics': {'followers_count': 4802,
#     'following_count': 4603,
#     'tweet_count': 3637,
#     'listed_count': 183},
#    'username': 'GreenPoliCAN',
#    'id': '288303533',
#    'name': 'Green Politics CND',
#    'verified': False,
#    'description': 'As we enter 4 years of Harper, remember that each individual who wishes change can be that change every single day.  Give them hell @ElizabethMay in Ottawa !!!',
#    'location': 'Canada'},
#   {'public_metrics': {'followers_count': 24,
#     'following_count': 100,
#     'tweet_count': 232,
#     'listed_count': 1},
#    'username': 'amomwithaview',
#    'id': '622874393',
#    'name': 'Serena Schmidt',
#    'verified': False,
#    'description': 'Wife, mom, teacher, runner, reader, seamstress, daughter of God',
#    'location': 'USA'},
#   {'public_metrics': {'followers_count': 5712,
#     'following_count': 945,
#     'tweet_count': 28935,
#     'listed_count': 251},
#    'username': 'BeautyFrmAshes',
#    'id': '78761160',
#    'name': 'Beauty From Ashes™',
#    'verified': False,
#    'description': 'Survivor-led since 2002, fighting slavery w/🎨🐎🦋 Specializing in Equine, Art & Trauma Therapy, Mentoring, Retreats, Consulting, Training & Art Production',
#    'location': 'Tampa, FL'},
#   {'public_metrics': {'followers_count': 8312897,
#     'following_count': 433,
#     'tweet_count': 5426,
#     'listed_count': 6807},
#    'username': 'carrieunderwood',
#    'id': '386244525',
#    'name': 'Carrie Underwood',
#    'verified': True,
#    'description': "Mike's wife, Isaiah’s and Jacob’s mom. Also, mom to fur babies Ace, Penny Jean and Zero. Blessed and grateful! The official Twitter account for Carrie Underwood",
# ...
#     'tweet_count': 9290,
#     'listed_count': 9180},
#    'username': 'MaxLucado',
#    'id': '16588111',
#    'name': 'Max Lucado',
#    'verified': True,
#    'description': 'Pastor and NYT bestselling author. New book, Begin Again, is available wherever books are sold.',
#    'location': 'San Antonio'},
#   {'public_metrics': {'followers_count': 6293929,
#     'following_count': 141,
#     'tweet_count': 67869,
#     'listed_count': 15555},
#    'username': 'JoyceMeyer',
#    'id': '15809249',
#    'name': 'Joyce Meyer',
#    'verified': True,
#    'description': 'Sharing Christ - Loving People   *All responses are moderated by Joyce Meyer Ministries. Tweets from Joyce will be signed accordingly.',
#    'location': 'St. Louis, MO'},
#   {'public_metrics': {'followers_count': 135684,
#     'following_count': 2,
#     'tweet_count': 8874,
#     'listed_count': 1708},
#    'username': 'chuckswindoll',
#    'id': '27748700',
#    'name': 'Chuck Swindoll',
#    'verified': False,
#    'description': 'Accurate, Clear, and Practical Bible Teaching',
#    'location': 'Frisco, Texas'},
#   {'public_metrics': {'followers_count': 21649,
#     'following_count': 180,
#     'tweet_count': 2881,
#     'listed_count': 236},
#    'username': 'revjamesrobison',
#    'id': '45011095',
#    'name': 'James Robison',
#    'verified': False,
#    'description': '',
#    'location': 'Fort Worth, Texas'},
#   {'public_metrics': {'followers_count': 3071,
#     'following_count': 2858,
#     'tweet_count': 2737,
#     'listed_count': 84},
#    'username': 'Bill_Mrf',
#    'id': '19550641',
#    'name': 'Bill Wilson',
#    'verified': False,
#    'description': 'Chairman of @mrf_insight. Fighting tyranny, elitism, and exploitation for over 30 years. Pro America, pro working class, anti-globalism. Parler- RealBillWilson',
#    'location': 'Fairfax, VA'},
#   {'public_metrics': {'followers_count': 687805,
#     'following_count': 695,
#     'tweet_count': 133070,
#     'listed_count': 6399},
#    'username': 'theblaze',
#    'id': '10774652',
#    'name': 'TheBlaze',
#    'verified': True,
#    'description': 'News and entertainment for people who love America',
#    'location': 'Dallas, TX'},
#   {'public_metrics': {'followers_count': 188986,
#     'following_count': 304,
#     'tweet_count': 21149,
#     'listed_count': 1830},
#    'username': 'greglaurie',
#    'id': '19353402',
#    'name': 'Greg Laurie',
#    'verified': True,
#    'description': 'Pastor and Evangelist :: Knowing God and Making Him Known :: Maintained by Pastor Greg and the @harvestriv team',
#    'location': 'Southern California'},
#   {'public_metrics': {'followers_count': 272951,
#     'following_count': 184,
#     'tweet_count': 11847,
#     'listed_count': 1730},
#    'username': 'jamesmacdonald',
#    'id': '32411258',
#    'name': 'James MacDonald',
#    'verified': True,
#    'description': 'Revelation 1:2 - For the Word of God and the testimony of Jesus Christ',
#    'location': 'Chicago, Illinois'},
#   {'public_metrics': {'followers_count': 3893,
#     'following_count': 1770,
#     'tweet_count': 1279,
#     'listed_count': 55},
#    'username': 'mikemacintosh',
#    'id': '215807428',
#    'name': 'Mike Macintosh',
#    'verified': False,
#    'description': 'Friend of God',
#    'location': 'San Diego'},
#   {'public_metrics': {'followers_count': 188811,
#     'following_count': 27587,
#     'tweet_count': 41538,
#     'listed_count': 1917},
#    'username': 'TPPatriots',
#    'id': '86177206',
#    'name': 'Tea Party Patriots',
#    'verified': True,
#    'description': 'Official Grassroots American Movement | Personal Freedom | Economic Freedom | Debt Free Future',
#    'location': 'USA'},
#   {'public_metrics': {'followers_count': 494250,
#     'following_count': 1691,
#     'tweet_count': 32833,
#     'listed_count': 2680},
#    'username': 'ShannonBream',
#    'id': '18983793',
#    'name': 'Shannon Bream',
#    'verified': True,
#    'description': 'Silence in the face of evil is itself evil: God will not hold us guiltless. Not to speak is to speak. Not to act is to act. -Bonhoeffer',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 5769,
#     'following_count': 30,
#     'tweet_count': 238,
#     'listed_count': 129},
#    'username': 'JohnErrante',
#    'id': '272492316',
#    'name': 'John Errante',
#    'verified': False,
#    'description': "Marketing Professional, Army Veteran, and Student of the World. Tweets are my own. I don't check my DMs. #sgf",
#    'location': 'Springfield, MO'},
#   {'public_metrics': {'followers_count': 307,
#     'following_count': 1086,
#     'tweet_count': 97,
#     'listed_count': 2},
#    'username': 'FriendsofMeMtns',
#    'id': '191188996',
#    'name': 'Friends of ME Mtns.',
#    'verified': False,
#    'description': 'Maine mountains are being DESTROYED for industrial wind turbines that INCREASE electricity costs and DON’T REDUCE fossil fuel emissions. PRICE IS TOO HIGH!',
#    'location': 'Wilton, ME'},
#   {'public_metrics': {'followers_count': 4841,
#     'following_count': 612,
#     'tweet_count': 5642,
#     'listed_count': 288},
#    'username': 'WSJIdeasMarket',
#    'id': '263342687',
#    'name': 'WSJ Ideas Market',
#    'verified': False,
#    'description': "Delivering the latest news and commentary from the world of ideas, brought to you by The Wall Street Journal's Review section."},
#   {'public_metrics': {'followers_count': 119800,
#     'following_count': 9348,
#     'tweet_count': 37390,
#     'listed_count': 970},
#    'username': 'JordanSekulow',
#    'id': '20686232',
#    'name': 'Jordan Sekulow',
#    'verified': True,
#    'description': 'husband to @annasekulow, father, attorney, radio show host, author of The Next Red Wave, @Newsmax contributor',
#    'location': 'TN and DC'},
#   {'public_metrics': {'followers_count': 2402,
#     'following_count': 324,
#     'tweet_count': 13468,
#     'listed_count': 86},
#    'username': 'Chris_C_Horner',
#    'id': '759564763',
#    'name': 'Chris Horner',
#    'verified': False,
#    'description': 'Lawyer for policy groups, author of NYT bestseller The Politically Incorrect Guide to Global Warming & Environmentalism, among others',
#    'location': 'Virginia'},
#   {'public_metrics': {'followers_count': 54859,
#     'following_count': 2949,
#     'tweet_count': 171,
#     'listed_count': 1087},
#    'username': 'BecketAdams',
#    'id': '454119389',
#    'name': 'tsar becket adams',
#    'verified': True,
#    'description': 'Commentary @dcexaminer. Former @UnfilteredSE.\n\nSubstack: https://t.co/ONTwCRaxCk\nYouTube: https://t.co/UZIQLPcLFA',
#    'location': 'D.C. via South Bend'},
#   {'public_metrics': {'followers_count': 478860,
#     'following_count': 172,
#     'tweet_count': 15673,
#     'listed_count': 1773},
#    'username': 'JaySekulow',
#    'id': '171632862',
#    'name': 'Jay Sekulow',
#    'verified': True,
#    'description': 'Chief Counsel @ACLJ. #1 NY Times Best Selling author. #RiseofISIS & #Undemocratic. Dedicated to defending the #Constitution.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 1228,
#     'following_count': 1002,
#     'tweet_count': 4190,
#     'listed_count': 37},
#    'username': 'energyrabbit',
#    'id': '44643411',
#    'name': 'Marita K Noon',
#    'verified': False,
#    'description': 'Executive Director at Energy Makes America Great Inc. the advocacy arm of the Citizens’ Alliance for Responsible Energy. Columnist for http://t.co/qKEfDQkP1s',
#    'location': 'New Mexico'},
#   {'public_metrics': {'followers_count': 4213900,
#     'following_count': 2483,
#     'tweet_count': 14693,
#     'listed_count': 16448},
#    'username': 'marcorubio',
#    'id': '15745368',
#    'name': 'Marco Rubio',
#    'verified': True,
#    'description': 'Banned in & sanctioned by China,Follower of Christ,Husband,Father, Proud AMERICAN, US Senator for Florida, #GatorNation & #FinsUp.Official tweets @SenRubioPress',
#    'location': 'United States'},
#   {'public_metrics': {'followers_count': 3515261,
#     'following_count': 243,
#     'tweet_count': 14715,
#     'listed_count': 11612},
#    'username': 'SpeakerRyan',
#    'id': '18916432',
#    'name': 'Paul Ryan',
#    'verified': True,
#    'description': 'Office of the 54th Speaker of the House, Paul Ryan.',
#    'location': 'Janesville, WI'},
#   {'public_metrics': {'followers_count': 2136160,
#     'following_count': 299,
#     'tweet_count': 2018,
#     'listed_count': 13967},
#    'username': 'MittRomney',
#    'id': '50055701',
#    'name': 'Mitt Romney',
#    'verified': True,
#    'description': 'Husband, Father, Grandfather, Former Governor, U.S. Senator (R-UT). Follow @SenatorRomney for official updates.',
#    'location': 'Holladay, UT'},
#   {'public_metrics': {'followers_count': 40290,
#     'following_count': 931,
#     'tweet_count': 5685,
#     'listed_count': 587},
#    'username': 'GerriWillisFBN',
#    'id': '54900089',
#    'name': 'Gerri Willis',
#    'verified': True,
#    'description': "Watch Gerri's reports on @FoxBusiness Network and @FoxNews channel.",
#    'location': 'New York, NY'},
#   {'public_metrics': {'followers_count': 30,
#     'following_count': 22,
#     'tweet_count': 11,
#     'listed_count': 1},
#    'username': 'davidasman',
#    'id': '93327781',
#    'name': 'David Asman',
#    'verified': False,
#    'description': ''},
#   {'public_metrics': {'followers_count': 6453,
#     'following_count': 22,
#     'tweet_count': 27351,
#     'listed_count': 173},
#    'username': 'TownhallColumns',
#    'id': '336025704',
#    'name': 'Townhall Columnists',
#    'verified': False,
#    'description': 'Conservative Columnists and Political Commentary from http://t.co/STx5xuY0dC',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 173468,
#     'following_count': 1051,
#     'tweet_count': 73150,
#     'listed_count': 2672},
#    'username': 'townhallcom',
#    'id': '28614262',
#    'name': 'Townhall.com',
#    'verified': True,
#    'description': 'Townhall.com is the #1 conservative website with political commentary from over 100 columnists and a community of millions of grassroots conservatives.',
#    'location': 'Washington D.C.'},
#   {'public_metrics': {'followers_count': 18015,
#     'following_count': 2086,
#     'tweet_count': 18614,
#     'listed_count': 701},
#    'username': 'IERenergy',
#    'id': '15918353',
#    'name': 'Institute for Energy Research',
#    'verified': True,
#    'description': 'The Institute for Energy Research is a non-profit foundation that conducts analysis on the functions, operations, and government regulation of energy markets.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 35607,
#     'following_count': 10824,
#     'tweet_count': 35289,
#     'listed_count': 707},
#    'username': 'Heritage_Action',
#    'id': '130600206',
#    'name': 'Heritage Action',
#    'verified': True,
#    'description': '@Heritage_Action turns conservative ideas into reality on Capitol Hill. \nAffiliated with @heritage.  RTs ≠ endorsements. Text PROTECT to 51776.',
#    'location': 'America'},
#   {'public_metrics': {'followers_count': 268460,
#     'following_count': 9511,
#     'tweet_count': 116032,
#     'listed_count': 3560},
#    'username': 'FreedomWorks',
#    'id': '14730894',
#    'name': 'FreedomWorks',
#    'verified': True,
#    'description': 'FreedomWorks is one of America’s largest grassroots organizations advocating for less government.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 18880486,
#     'following_count': 1036,
#     'tweet_count': 338954,
#     'listed_count': 120383},
#    'username': 'WSJ',
#    'id': '3108351',
#    'name': 'The Wall Street Journal',
#    'verified': True,
#    'description': 'Sign up for our newsletters and email alerts: https://t.co/WFU7oLKkip',
#    'location': 'New York, NY'},
#   {'public_metrics': {'followers_count': 29459,
#     'following_count': 168,
#     'tweet_count': 3826,
#     'listed_count': 503},
#    'username': 'DavidBartonWB',
#    'id': '242770475',
#    'name': 'David Barton',
#    'verified': False,
#    'description': "Founder of WallBuilders, author and speaker on America's forgotten religious foundation. https://t.co/awh8fYaYfa",
#    'location': 'Texas'},
#   {'public_metrics': {'followers_count': 5656,
#     'following_count': 2942,
#     'tweet_count': 10170,
#     'listed_count': 130},
#    'username': 'LimitGovt',
#    'id': '90649509',
#    'name': 'Americans for Limited Government',
#    'verified': False,
#    'description': 'We fight for the survival of America by restoring constitutionally limited government, allowing individuals to pursue life, liberty and happiness.',
#    'location': 'Fairfax, VA'},
#   {'public_metrics': {'followers_count': 628129,
#     'following_count': 26489,
#     'tweet_count': 102931,
#     'listed_count': 10220},
#    'username': 'Heritage',
#    'id': '10168082',
#    'name': 'Heritage Foundation',
#    'verified': True,
#    'description': 'Devoted to the principles of free enterprise, limited government, individual freedom, traditional American values, and a strong national defense.',
#    'location': 'Washington, DC'},
#   {'public_metrics': {'followers_count': 948,
#     'following_count': 764,
#     'tweet_count': 871,
#     'listed_count': 72},
#    'username': 'cooler_heads',
#    'id': '20066456',
#    'name': 'GlobalWarming.org',
#    'verified': False,
#    'description': 'May cooler heads prevail',
#    'location': 'Washington D.C.'},
#   {'public_metrics': {'followers_count': 5216,
#     'following_count': 858,
#     'tweet_count': 12108,
#     'listed_count': 248},
#    'username': 'pwrhungry',
#    'id': '136310943',
#    'name': 'Robert Bryce',
#    'verified': False,
#    'description': 'Author, journalist, podcaster. Energy, power, birds, basketball. @FREOPP Book: A Question of Power. Film: https://t.co/xoc68QEpL0. https://t.co/rEKbhqDaHi \nRT ≤ 0',
#    'location': 'Austin, TX'},
#   {'public_metrics': {'followers_count': 279,
#     'following_count': 5,
#     'tweet_count': 1839,
#     'listed_count': 24},
#    'username': 'questionAGW',
#    'id': '142911921',
#    'name': 'Russell Cook',
#    'verified': False,
#    'description': "AGW = anthropogenic (man-caused) global warming.\r\n\r\nI'm told skeptic climate scientists are corrupt. It appears their accusers have done nothing to prove it.",
#    'location': 'USA'},
#   {'public_metrics': {'followers_count': 2047384,
#     'following_count': 4164,
#     'tweet_count': 5810,
#     'listed_count': 4053},
#    'username': 'ShareThis',
#    'id': '14116807',
#    'name': 'ShareThis',
#    'verified': False,
#    'description': 'Unlocking the Power of Global Digital Behavior',
#    'location': 'Palo Alto, CA'},
#   {'public_metrics': {'followers_count': 15948,
#     'following_count': 313,
#     'tweet_count': 729,
#     'listed_count': 371},
#    'username': 'MikeBeebeAR',
#    'id': '39556712',
#    'name': 'Mike Beebe',
#    'verified': False,
#    'description': "Arkansas's 45th Governor. Account maintained by former staff.",
#    'location': 'Searcy, Arkansas'},
#   {'public_metrics': {'followers_count': 1009,
#     'following_count': 1234,
#     'tweet_count': 4432,
#     'listed_count': 18},
#    'username': 'swindlewind',
#    'id': '563421246',
#    'name': 'sWINDle Wind Energy',
#    'verified': False,
#    'description': 'calling for the TRUE COST of wind energy and REAL grid performance analysis & measurement of fuel consumption with & without wind - neither is being done now'},
#   {'public_metrics': {'followers_count': 2055722,
#     'following_count': 17341,
#     'tweet_count': 78419,
#     'listed_count': 0},
#    'username': 'michellemalkin',
#    'id': '15976697',
#    'name': 'Michelle Malkin',
#    'verified': True,
#    'description': 'REDACTED',
#    'location': 'USA'},
#   {'public_metrics': {'followers_count': 2244,
#     'following_count': 86,
#     'tweet_count': 580,
#     'listed_count': 66},
#    'username': 'FBPowerandMoney',
#    'id': '169610198',
#    'name': 'Power and Money',
#    'verified': False,
#    'description': 'Watch Power and Money with David Asman every week night at 9 pm ET on Fox Business!',
#    'location': 'New York'},
#   {'public_metrics': {'followers_count': 1086141,
#     'following_count': 928,
#     'tweet_count': 35658,
#     'listed_count': 4084},
#    'username': 'ericbolling',
#    'id': '14839147',
#    'name': '🇺🇸ERIC BOLLING🇺🇸',
#    'verified': True,
#    'description': '“As Seen On TV” ........ (eric@ericbolling.com)'}],
#  'meta': {'result_count': 445, 'previous_token': 'I91SRE9NL52UOZZZ'}}

# %%
tokens = ['next_token','previous_token']

if any(t in a for t in tokens):
    print('nice')
